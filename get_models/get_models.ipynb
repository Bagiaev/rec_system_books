# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import save_npz, load_npz
import numpy as np
import pickle
from google.colab import drive

# Загрузите ваш датасет
books = pd.read_csv('clean_books.csv')

# ## Шаг 3: Создание и сохранение TF-IDF модели
# %%
# Инициализация TF-IDF
tfidf = TfidfVectorizer(
    stop_words='english',
    ngram_range=(1, 2),
    max_features=10000  # Можно увеличить для полного датасета
)

# Создание матрицы
print("Создание TF-IDF матрицы...")
tfidf_matrix = tfidf.fit_transform(books['title'].fillna(''))

# Сохранение модели и матрицы
print("Сохранение артефактов...")
with open('tfidf_vectorizer.pkl', 'wb') as f:
    pickle.dump(tfidf, f)
save_npz('tfidf_matrix.npz', tfidf_matrix)

# ## Шаг 4: Вычисление и сохранение матрицы схожести (по частям)
# %%
# Размер чанка (подбирается в зависимости от доступной RAM)
chunk_size = 2000
n_books = len(books)
similarity_matrix = np.zeros((n_books, n_books), dtype=np.float32)

for i in range(0, n_books, chunk_size):
    for j in range(0, n_books, chunk_size):
        print(f"Обработка блока {i//chunk_size+1}x{j//chunk_size+1}...")
        chunk_sim = cosine_similarity(
            tfidf_matrix[i:i+chunk_size],
            tfidf_matrix[j:j+chunk_size]
        )
        similarity_matrix[i:i+chunk_size, j:j+chunk_size] = chunk_sim

# Сохранение матрицы схожести
np.save('similarity_matrix.npy', similarity_matrix)

# ## Шаг 5: Сохранение метаданных
# %%
# Сохраняем индексы для быстрого поиска
book_indices = pd.Series(books.index, index=books['title'].str.lower()).to_dict()
with open('book_indices.pkl', 'wb') as f:
    pickle.dump(book_indices, f)

print("Все компоненты успешно сохранены!")
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Обработка блока 100x33...
# Обработка блока 100x34...
# Обработка блока 100x35...
# Обработка блока 100x36...
# Обработка блока 100x37...
# Обработка блока 100x38...
# Обработка блока 100x39...
# Обработка блока 100x40...
# Обработка блока 100x41...
# Обработка блока 100x42...
# Обработка блока 100x43...
# Обработка блока 100x44...
# Обработка блока 100x45...
# Обработка блока 100x46...
# Обработка блока 100x47...
# Обработка блока 100x48...
# Обработка блока 100x49...
# Обработка блока 100x50...
# Обработка блока 100x51...
# Обработка блока 100x52...
# Обработка блока 100x53...
# Обработка блока 100x54...
# Обработка блока 100x55...
# Обработка блока 100x56...
# Обработка блока 100x57...
# Обработка блока 100x58...
# Обработка блока 100x59...
# Обработка блока 100x60...
# Обработка блока 100x61...
# Обработка блока 100x62...
# Обработка блока 100x63...
# Обработка блока 100x64...
# Обработка блока 100x65...
# Обработка блока 100x66...
# Обработка блока 100x67...
# Обработка блока 100x68...
# Обработка блока 100x69...
# Обработка блока 100x70...
# Обработка блока 100x71...
# Обработка блока 100x72...
# Обработка блока 100x73...
# Обработка блока 100x74...
# Обработка блока 100x75...
# Обработка блока 100x76...
# Обработка блока 100x77...
# Обработка блока 100x78...
# Обработка блока 100x79...
# Обработка блока 100x80...
# Обработка блока 100x81...
# Обработка блока 100x82...
# Обработка блока 100x83...
# Обработка блока 100x84...
# Обработка блока 100x85...
# Обработка блока 100x86...
# Обработка блока 100x87...
# Обработка блока 100x88...
# Обработка блока 100x89...
# Обработка блока 100x90...
# Обработка блока 100x91...
# Обработка блока 100x92...
# Обработка блока 100x93...
# Обработка блока 100x94...
# Обработка блока 100x95...
# Обработка блока 100x96...
# Обработка блока 100x97...
# Обработка блока 100x98...
# Обработка блока 100x99...
# Обработка блока 100x100...
# Обработка блока 100x101...
# Обработка блока 100x102...
# Обработка блока 100x103...
# Обработка блока 100x104...
# Обработка блока 100x105...
# Обработка блока 100x106...
# Обработка блока 100x107...
# Обработка блока 100x108...
# Обработка блока 100x109...
# Обработка блока 100x110...
# Обработка блока 100x111...
# Обработка блока 100x112...
# Обработка блока 100x113...
# Обработка блока 100x114...
# Обработка блока 100x115...
# Обработка блока 100x116...
# Обработка блока 100x117...
# Обработка блока 100x118...
# Обработка блока 100x119...
# Обработка блока 100x120...
# Обработка блока 100x121...
# Обработка блока 100x122...
# Обработка блока 100x123...
# Обработка блока 100x124...
# Обработка блока 100x125...
# Обработка блока 100x126...
# Обработка блока 100x127...
# Обработка блока 100x128...
# Обработка блока 100x129...
# Обработка блока 100x130...
# Обработка блока 100x131...
# Обработка блока 100x132...
# Обработка блока 100x133...
# Обработка блока 100x134...
# Обработка блока 100x135...
# Обработка блока 100x136...
# Обработка блока 101x1...
# Обработка блока 101x2...
# Обработка блока 101x3...
# Обработка блока 101x4...
# Обработка блока 101x5...
# Обработка блока 101x6...
# Обработка блока 101x7...
# Обработка блока 101x8...
# Обработка блока 101x9...
# Обработка блока 101x10...
# Обработка блока 101x11...
# Обработка блока 101x12...
# Обработка блока 101x13...
# Обработка блока 101x14...
# Обработка блока 101x15...
# Обработка блока 101x16...
# Обработка блока 101x17...
# Обработка блока 101x18...
# Обработка блока 101x19...
# Обработка блока 101x20...
# Обработка блока 101x21...
# Обработка блока 101x22...
# Обработка блока 101x23...
# Обработка блока 101x24...
# Обработка блока 101x25...
# Обработка блока 101x26...
# Обработка блока 101x27...
# Обработка блока 101x28...
# Обработка блока 101x29...
# Обработка блока 101x30...
# Обработка блока 101x31...
# Обработка блока 101x32...
# Обработка блока 101x33...
# Обработка блока 101x34...
# Обработка блока 101x35...
# Обработка блока 101x36...
# Обработка блока 101x37...
# Обработка блока 101x38...
# Обработка блока 101x39...
# Обработка блока 101x40...
# Обработка блока 101x41...
# Обработка блока 101x42...
# Обработка блока 101x43...
# Обработка блока 101x44...
# Обработка блока 101x45...
# Обработка блока 101x46...
# Обработка блока 101x47...
# Обработка блока 101x48...
# Обработка блока 101x49...
# Обработка блока 101x50...
# Обработка блока 101x51...
# Обработка блока 101x52...
# Обработка блока 101x53...
# Обработка блока 101x54...
# Обработка блока 101x55...
# Обработка блока 101x56...
# Обработка блока 101x57...
# Обработка блока 101x58...
# Обработка блока 101x59...
# Обработка блока 101x60...
# Обработка блока 101x61...
# Обработка блока 101x62...
# Обработка блока 101x63...
# Обработка блока 101x64...
# Обработка блока 101x65...
# Обработка блока 101x66...
# Обработка блока 101x67...
# Обработка блока 101x68...
# Обработка блока 101x69...
# Обработка блока 101x70...
# Обработка блока 101x71...
# Обработка блока 101x72...
# Обработка блока 101x73...
# Обработка блока 101x74...
# Обработка блока 101x75...
# Обработка блока 101x76...
# Обработка блока 101x77...
# Обработка блока 101x78...
# Обработка блока 101x79...
# Обработка блока 101x80...
# Обработка блока 101x81...
# Обработка блока 101x82...
# Обработка блока 101x83...
# Обработка блока 101x84...
# Обработка блока 101x85...
# Обработка блока 101x86...
# Обработка блока 101x87...
# Обработка блока 101x88...
# Обработка блока 101x89...
# Обработка блока 101x90...
# Обработка блока 101x91...
# Обработка блока 101x92...
# Обработка блока 101x93...
# Обработка блока 101x94...
# Обработка блока 101x95...
# Обработка блока 101x96...
# Обработка блока 101x97...
# Обработка блока 101x98...
# Обработка блока 101x99...
# Обработка блока 101x100...
# Обработка блока 101x101...
# Обработка блока 101x102...
# Обработка блока 101x103...
# Обработка блока 101x104...
# Обработка блока 101x105...
# Обработка блока 101x106...
# Обработка блока 101x107...
# Обработка блока 101x108...
# Обработка блока 101x109...
# Обработка блока 101x110...
# Обработка блока 101x111...
# Обработка блока 101x112...
# Обработка блока 101x113...
# Обработка блока 101x114...
# Обработка блока 101x115...
# Обработка блока 101x116...
# Обработка блока 101x117...
# Обработка блока 101x118...
# Обработка блока 101x119...
# Обработка блока 101x120...
# Обработка блока 101x121...
# Обработка блока 101x122...
# Обработка блока 101x123...
# Обработка блока 101x124...
# Обработка блока 101x125...
# Обработка блока 101x126...
# Обработка блока 101x127...
# Обработка блока 101x128...
# Обработка блока 101x129...
# Обработка блока 101x130...
# Обработка блока 101x131...
# Обработка блока 101x132...
# Обработка блока 101x133...
# Обработка блока 101x134...
# Обработка блока 101x135...
# Обработка блока 101x136...
# Обработка блока 102x1...
# Обработка блока 102x2...
# Обработка блока 102x3...
# Обработка блока 102x4...
# Обработка блока 102x5...
# Обработка блока 102x6...
# Обработка блока 102x7...
# Обработка блока 102x8...
# Обработка блока 102x9...
# Обработка блока 102x10...
# Обработка блока 102x11...
# Обработка блока 102x12...
# Обработка блока 102x13...
# Обработка блока 102x14...
# Обработка блока 102x15...
# Обработка блока 102x16...
# Обработка блока 102x17...
# Обработка блока 102x18...
# Обработка блока 102x19...
# Обработка блока 102x20...
# Обработка блока 102x21...
# Обработка блока 102x22...
# Обработка блока 102x23...
# Обработка блока 102x24...
# Обработка блока 102x25...
# Обработка блока 102x26...
# Обработка блока 102x27...
# Обработка блока 102x28...
# Обработка блока 102x29...
# Обработка блока 102x30...
# Обработка блока 102x31...
# Обработка блока 102x32...
# Обработка блока 102x33...
# Обработка блока 102x34...
# Обработка блока 102x35...
# Обработка блока 102x36...
# Обработка блока 102x37...
# Обработка блока 102x38...
# Обработка блока 102x39...
# Обработка блока 102x40...
# Обработка блока 102x41...
# Обработка блока 102x42...
# Обработка блока 102x43...
# Обработка блока 102x44...
# Обработка блока 102x45...
# Обработка блока 102x46...
# Обработка блока 102x47...
# Обработка блока 102x48...
# Обработка блока 102x49...
# Обработка блока 102x50...
# Обработка блока 102x51...
# Обработка блока 102x52...
# Обработка блока 102x53...
# Обработка блока 102x54...
# Обработка блока 102x55...
# Обработка блока 102x56...
# Обработка блока 102x57...
# Обработка блока 102x58...
# Обработка блока 102x59...
# Обработка блока 102x60...
# Обработка блока 102x61...
# Обработка блока 102x62...
# Обработка блока 102x63...
# Обработка блока 102x64...
# Обработка блока 102x65...
# Обработка блока 102x66...
# Обработка блока 102x67...
# Обработка блока 102x68...
# Обработка блока 102x69...
# Обработка блока 102x70...
# Обработка блока 102x71...
# Обработка блока 102x72...
# Обработка блока 102x73...
# Обработка блока 102x74...
# Обработка блока 102x75...
# Обработка блока 102x76...
# Обработка блока 102x77...
# Обработка блока 102x78...
# Обработка блока 102x79...
# Обработка блока 102x80...
# Обработка блока 102x81...
# Обработка блока 102x82...
# Обработка блока 102x83...
# Обработка блока 102x84...
# Обработка блока 102x85...
# Обработка блока 102x86...
# Обработка блока 102x87...
# Обработка блока 102x88...
# Обработка блока 102x89...
# Обработка блока 102x90...
# Обработка блока 102x91...
# Обработка блока 102x92...
# Обработка блока 102x93...
# Обработка блока 102x94...
# Обработка блока 102x95...
# Обработка блока 102x96...
# Обработка блока 102x97...
# Обработка блока 102x98...
# Обработка блока 102x99...
# Обработка блока 102x100...
# Обработка блока 102x101...
# Обработка блока 102x102...
# Обработка блока 102x103...
# Обработка блока 102x104...
# Обработка блока 102x105...
# Обработка блока 102x106...
# Обработка блока 102x107...
# Обработка блока 102x108...
# Обработка блока 102x109...
# Обработка блока 102x110...
# Обработка блока 102x111...
# Обработка блока 102x112...
# Обработка блока 102x113...
# Обработка блока 102x114...
# Обработка блока 102x115...
# Обработка блока 102x116...
# Обработка блока 102x117...
# Обработка блока 102x118...
# Обработка блока 102x119...
# Обработка блока 102x120...
# Обработка блока 102x121...
# Обработка блока 102x122...
# Обработка блока 102x123...
# Обработка блока 102x124...
# Обработка блока 102x125...
# Обработка блока 102x126...
# Обработка блока 102x127...
# Обработка блока 102x128...
# Обработка блока 102x129...
# Обработка блока 102x130...
# Обработка блока 102x131...
# Обработка блока 102x132...
# Обработка блока 102x133...
# Обработка блока 102x134...
# Обработка блока 102x135...
# Обработка блока 102x136...
# Обработка блока 103x1...
# Обработка блока 103x2...
# Обработка блока 103x3...
# Обработка блока 103x4...
# Обработка блока 103x5...
# Обработка блока 103x6...
# Обработка блока 103x7...
# Обработка блока 103x8...
# Обработка блока 103x9...
# Обработка блока 103x10...
# Обработка блока 103x11...
# Обработка блока 103x12...
# Обработка блока 103x13...
# Обработка блока 103x14...
# Обработка блока 103x15...
# Обработка блока 103x16...
# Обработка блока 103x17...
# Обработка блока 103x18...
# Обработка блока 103x19...
# Обработка блока 103x20...
# Обработка блока 103x21...
# Обработка блока 103x22...
# Обработка блока 103x23...
# Обработка блока 103x24...
# Обработка блока 103x25...
# Обработка блока 103x26...
# Обработка блока 103x27...
# Обработка блока 103x28...
# Обработка блока 103x29...
# Обработка блока 103x30...
# Обработка блока 103x31...
# Обработка блока 103x32...
# Обработка блока 103x33...
# Обработка блока 103x34...
# Обработка блока 103x35...
# Обработка блока 103x36...
# Обработка блока 103x37...
# Обработка блока 103x38...
# Обработка блока 103x39...
# Обработка блока 103x40...
# Обработка блока 103x41...
# Обработка блока 103x42...
# Обработка блока 103x43...
# Обработка блока 103x44...
# Обработка блока 103x45...
# Обработка блока 103x46...
# Обработка блока 103x47...
# Обработка блока 103x48...
# Обработка блока 103x49...
# Обработка блока 103x50...
# Обработка блока 103x51...
# Обработка блока 103x52...
# Обработка блока 103x53...
# Обработка блока 103x54...
# Обработка блока 103x55...
# Обработка блока 103x56...
# Обработка блока 103x57...
# Обработка блока 103x58...
# Обработка блока 103x59...
# Обработка блока 103x60...
# Обработка блока 103x61...
# Обработка блока 103x62...
# Обработка блока 103x63...
# Обработка блока 103x64...
# Обработка блока 103x65...
# Обработка блока 103x66...
# Обработка блока 103x67...
# Обработка блока 103x68...
# Обработка блока 103x69...
# Обработка блока 103x70...
# Обработка блока 103x71...
# Обработка блока 103x72...
# Обработка блока 103x73...
# Обработка блока 103x74...
# Обработка блока 103x75...
# Обработка блока 103x76...
# Обработка блока 103x77...
# Обработка блока 103x78...
# Обработка блока 103x79...
# Обработка блока 103x80...
# Обработка блока 103x81...
# Обработка блока 103x82...
# Обработка блока 103x83...
# Обработка блока 103x84...
# Обработка блока 103x85...
# Обработка блока 103x86...
# Обработка блока 103x87...
# Обработка блока 103x88...
# Обработка блока 103x89...
# Обработка блока 103x90...
# Обработка блока 103x91...
# Обработка блока 103x92...
# Обработка блока 103x93...
# Обработка блока 103x94...
# Обработка блока 103x95...
# Обработка блока 103x96...
# Обработка блока 103x97...
# Обработка блока 103x98...
# Обработка блока 103x99...
# Обработка блока 103x100...
# Обработка блока 103x101...
# Обработка блока 103x102...
# Обработка блока 103x103...
# Обработка блока 103x104...
# Обработка блока 103x105...
# Обработка блока 103x106...
# Обработка блока 103x107...
# Обработка блока 103x108...
# Обработка блока 103x109...
# Обработка блока 103x110...
# Обработка блока 103x111...
# Обработка блока 103x112...
# Обработка блока 103x113...
# Обработка блока 103x114...
# Обработка блока 103x115...
# Обработка блока 103x116...
# Обработка блока 103x117...
# Обработка блока 103x118...
# Обработка блока 103x119...
# Обработка блока 103x120...
# Обработка блока 103x121...
# Обработка блока 103x122...
# Обработка блока 103x123...
# Обработка блока 103x124...
# Обработка блока 103x125...
# Обработка блока 103x126...
# Обработка блока 103x127...
# Обработка блока 103x128...
# Обработка блока 103x129...
# Обработка блока 103x130...
# Обработка блока 103x131...
# Обработка блока 103x132...
# Обработка блока 103x133...
# Обработка блока 103x134...
# Обработка блока 103x135...
# Обработка блока 103x136...
# Обработка блока 104x1...
# Обработка блока 104x2...
# Обработка блока 104x3...
# Обработка блока 104x4...
# Обработка блока 104x5...
# Обработка блока 104x6...
# Обработка блока 104x7...
# Обработка блока 104x8...
# Обработка блока 104x9...
# Обработка блока 104x10...
# Обработка блока 104x11...
# Обработка блока 104x12...
# Обработка блока 104x13...
# Обработка блока 104x14...
# Обработка блока 104x15...
# Обработка блока 104x16...
# Обработка блока 104x17...
# Обработка блока 104x18...
# Обработка блока 104x19...
# Обработка блока 104x20...
# Обработка блока 104x21...
# Обработка блока 104x22...
# Обработка блока 104x23...
# Обработка блока 104x24...
# Обработка блока 104x25...
# Обработка блока 104x26...
# Обработка блока 104x27...
# Обработка блока 104x28...
# Обработка блока 104x29...
# Обработка блока 104x30...
# Обработка блока 104x31...
# Обработка блока 104x32...
# Обработка блока 104x33...
# Обработка блока 104x34...
# Обработка блока 104x35...
# Обработка блока 104x36...
# Обработка блока 104x37...
# Обработка блока 104x38...
# Обработка блока 104x39...
# Обработка блока 104x40...
# Обработка блока 104x41...
# Обработка блока 104x42...
# Обработка блока 104x43...
# Обработка блока 104x44...
# Обработка блока 104x45...
# Обработка блока 104x46...
# Обработка блока 104x47...
# Обработка блока 104x48...
# Обработка блока 104x49...
# Обработка блока 104x50...
# Обработка блока 104x51...
# Обработка блока 104x52...
# Обработка блока 104x53...
# Обработка блока 104x54...
# Обработка блока 104x55...
# Обработка блока 104x56...
# Обработка блока 104x57...
# Обработка блока 104x58...
# Обработка блока 104x59...
# Обработка блока 104x60...
# Обработка блока 104x61...
# Обработка блока 104x62...
# Обработка блока 104x63...
# Обработка блока 104x64...
# Обработка блока 104x65...
# Обработка блока 104x66...
# Обработка блока 104x67...
# Обработка блока 104x68...
# Обработка блока 104x69...
# Обработка блока 104x70...
# Обработка блока 104x71...
# Обработка блока 104x72...
# Обработка блока 104x73...
# Обработка блока 104x74...
# Обработка блока 104x75...
# Обработка блока 104x76...
# Обработка блока 104x77...
# Обработка блока 104x78...
# Обработка блока 104x79...
# Обработка блока 104x80...
# Обработка блока 104x81...
# Обработка блока 104x82...
# Обработка блока 104x83...
# Обработка блока 104x84...
# Обработка блока 104x85...
# Обработка блока 104x86...
# Обработка блока 104x87...
# Обработка блока 104x88...
# Обработка блока 104x89...
# Обработка блока 104x90...
# Обработка блока 104x91...
# Обработка блока 104x92...
# Обработка блока 104x93...
# Обработка блока 104x94...
# Обработка блока 104x95...
# Обработка блока 104x96...
# Обработка блока 104x97...
# Обработка блока 104x98...
# Обработка блока 104x99...
# Обработка блока 104x100...
# Обработка блока 104x101...
# Обработка блока 104x102...
# Обработка блока 104x103...
# Обработка блока 104x104...
# Обработка блока 104x105...
# Обработка блока 104x106...
# Обработка блока 104x107...
# Обработка блока 104x108...
# Обработка блока 104x109...
# Обработка блока 104x110...
# Обработка блока 104x111...
# Обработка блока 104x112...
# Обработка блока 104x113...
# Обработка блока 104x114...
# Обработка блока 104x115...
# Обработка блока 104x116...
# Обработка блока 104x117...
# Обработка блока 104x118...
# Обработка блока 104x119...
# Обработка блока 104x120...
# Обработка блока 104x121...
# Обработка блока 104x122...
# Обработка блока 104x123...
# Обработка блока 104x124...
# Обработка блока 104x125...
# Обработка блока 104x126...
# Обработка блока 104x127...
# Обработка блока 104x128...
# Обработка блока 104x129...
# Обработка блока 104x130...
# Обработка блока 104x131...
# Обработка блока 104x132...
# Обработка блока 104x133...
# Обработка блока 104x134...
# Обработка блока 104x135...
# Обработка блока 104x136...
# Обработка блока 105x1...
# Обработка блока 105x2...
# Обработка блока 105x3...
# Обработка блока 105x4...
# Обработка блока 105x5...
# Обработка блока 105x6...
# Обработка блока 105x7...
# Обработка блока 105x8...
# Обработка блока 105x9...
# Обработка блока 105x10...
# Обработка блока 105x11...
# Обработка блока 105x12...
# Обработка блока 105x13...
# Обработка блока 105x14...
# Обработка блока 105x15...
# Обработка блока 105x16...
# Обработка блока 105x17...
# Обработка блока 105x18...
# Обработка блока 105x19...
# Обработка блока 105x20...
# Обработка блока 105x21...
# Обработка блока 105x22...
# Обработка блока 105x23...
# Обработка блока 105x24...
# Обработка блока 105x25...
# Обработка блока 105x26...
# Обработка блока 105x27...
# Обработка блока 105x28...
# Обработка блока 105x29...
# Обработка блока 105x30...
# Обработка блока 105x31...
# Обработка блока 105x32...
# Обработка блока 105x33...
# Обработка блока 105x34...
# Обработка блока 105x35...
# Обработка блока 105x36...
# Обработка блока 105x37...
# Обработка блока 105x38...
# Обработка блока 105x39...
# Обработка блока 105x40...
# Обработка блока 105x41...
# Обработка блока 105x42...
# Обработка блока 105x43...
# Обработка блока 105x44...
# Обработка блока 105x45...
# Обработка блока 105x46...
# Обработка блока 105x47...
# Обработка блока 105x48...
# Обработка блока 105x49...
# Обработка блока 105x50...
# Обработка блока 105x51...
# Обработка блока 105x52...
# Обработка блока 105x53...
# Обработка блока 105x54...
# Обработка блока 105x55...
# Обработка блока 105x56...
# Обработка блока 105x57...
# Обработка блока 105x58...
# Обработка блока 105x59...
# Обработка блока 105x60...
# Обработка блока 105x61...
# Обработка блока 105x62...
# Обработка блока 105x63...
# Обработка блока 105x64...
# Обработка блока 105x65...
# Обработка блока 105x66...
# Обработка блока 105x67...
# Обработка блока 105x68...
# Обработка блока 105x69...
# Обработка блока 105x70...
# Обработка блока 105x71...
# Обработка блока 105x72...
# Обработка блока 105x73...
# Обработка блока 105x74...
# Обработка блока 105x75...
# Обработка блока 105x76...
# Обработка блока 105x77...
# Обработка блока 105x78...
# Обработка блока 105x79...
# Обработка блока 105x80...
# Обработка блока 105x81...
# Обработка блока 105x82...
# Обработка блока 105x83...
# Обработка блока 105x84...
# Обработка блока 105x85...
# Обработка блока 105x86...
# Обработка блока 105x87...
# Обработка блока 105x88...
# Обработка блока 105x89...
# Обработка блока 105x90...
# Обработка блока 105x91...
# Обработка блока 105x92...
# Обработка блока 105x93...
# Обработка блока 105x94...
# Обработка блока 105x95...
# Обработка блока 105x96...
# Обработка блока 105x97...
# Обработка блока 105x98...
# Обработка блока 105x99...
# Обработка блока 105x100...
# Обработка блока 105x101...
# Обработка блока 105x102...
# Обработка блока 105x103...
# Обработка блока 105x104...
# Обработка блока 105x105...
# Обработка блока 105x106...
# Обработка блока 105x107...
# Обработка блока 105x108...
# Обработка блока 105x109...
# Обработка блока 105x110...
# Обработка блока 105x111...
# Обработка блока 105x112...
# Обработка блока 105x113...
# Обработка блока 105x114...
# Обработка блока 105x115...
# Обработка блока 105x116...
# Обработка блока 105x117...
# Обработка блока 105x118...
# Обработка блока 105x119...
# Обработка блока 105x120...
# Обработка блока 105x121...
# Обработка блока 105x122...
# Обработка блока 105x123...
# Обработка блока 105x124...
# Обработка блока 105x125...
# Обработка блока 105x126...
# Обработка блока 105x127...
# Обработка блока 105x128...
# Обработка блока 105x129...
# Обработка блока 105x130...
# Обработка блока 105x131...
# Обработка блока 105x132...
# Обработка блока 105x133...
# Обработка блока 105x134...
# Обработка блока 105x135...
# Обработка блока 105x136...
# Обработка блока 106x1...
# Обработка блока 106x2...
# Обработка блока 106x3...
# Обработка блока 106x4...
# Обработка блока 106x5...
# Обработка блока 106x6...
# Обработка блока 106x7...
# Обработка блока 106x8...
# Обработка блока 106x9...
# Обработка блока 106x10...
# Обработка блока 106x11...
# Обработка блока 106x12...
# Обработка блока 106x13...
# Обработка блока 106x14...
# Обработка блока 106x15...
# Обработка блока 106x16...
# Обработка блока 106x17...
# Обработка блока 106x18...
# Обработка блока 106x19...
# Обработка блока 106x20...
# Обработка блока 106x21...
# Обработка блока 106x22...
# Обработка блока 106x23...
# Обработка блока 106x24...
# Обработка блока 106x25...
# Обработка блока 106x26...
# Обработка блока 106x27...
# Обработка блока 106x28...
# Обработка блока 106x29...
# Обработка блока 106x30...
# Обработка блока 106x31...
# Обработка блока 106x32...
# Обработка блока 106x33...
# Обработка блока 106x34...
# Обработка блока 106x35...
# Обработка блока 106x36...
# Обработка блока 106x37...
# Обработка блока 106x38...
# Обработка блока 106x39...
# Обработка блока 106x40...
# Обработка блока 106x41...
# Обработка блока 106x42...
# Обработка блока 106x43...
# Обработка блока 106x44...
# Обработка блока 106x45...
# Обработка блока 106x46...
# Обработка блока 106x47...
# Обработка блока 106x48...
# Обработка блока 106x49...
# Обработка блока 106x50...
# Обработка блока 106x51...
# Обработка блока 106x52...
# Обработка блока 106x53...
# Обработка блока 106x54...
# Обработка блока 106x55...
# Обработка блока 106x56...
# Обработка блока 106x57...
# Обработка блока 106x58...
# Обработка блока 106x59...
# Обработка блока 106x60...
# Обработка блока 106x61...
# Обработка блока 106x62...
# Обработка блока 106x63...
# Обработка блока 106x64...
# Обработка блока 106x65...
# Обработка блока 106x66...
# Обработка блока 106x67...
# Обработка блока 106x68...
# Обработка блока 106x69...
# Обработка блока 106x70...
# Обработка блока 106x71...
# Обработка блока 106x72...
# Обработка блока 106x73...
# Обработка блока 106x74...
# Обработка блока 106x75...
# Обработка блока 106x76...
# Обработка блока 106x77...
# Обработка блока 106x78...
# Обработка блока 106x79...
# Обработка блока 106x80...
# Обработка блока 106x81...
# Обработка блока 106x82...
# Обработка блока 106x83...
# Обработка блока 106x84...
# Обработка блока 106x85...
# Обработка блока 106x86...
# Обработка блока 106x87...
# Обработка блока 106x88...
# Обработка блока 106x89...
# Обработка блока 106x90...
# Обработка блока 106x91...
# Обработка блока 106x92...
# Обработка блока 106x93...
# Обработка блока 106x94...
# Обработка блока 106x95...
# Обработка блока 106x96...
# Обработка блока 106x97...
# Обработка блока 106x98...
# Обработка блока 106x99...
# Обработка блока 106x100...
# Обработка блока 106x101...
# Обработка блока 106x102...
# Обработка блока 106x103...
# Обработка блока 106x104...
# Обработка блока 106x105...
# Обработка блока 106x106...
# Обработка блока 106x107...
# Обработка блока 106x108...
# Обработка блока 106x109...
# Обработка блока 106x110...
# Обработка блока 106x111...
# Обработка блока 106x112...
# Обработка блока 106x113...
# Обработка блока 106x114...
# Обработка блока 106x115...
# Обработка блока 106x116...
# Обработка блока 106x117...
# Обработка блока 106x118...
# Обработка блока 106x119...
# Обработка блока 106x120...
# Обработка блока 106x121...
# Обработка блока 106x122...
# Обработка блока 106x123...
# Обработка блока 106x124...
# Обработка блока 106x125...
# Обработка блока 106x126...
# Обработка блока 106x127...
# Обработка блока 106x128...
# Обработка блока 106x129...
# Обработка блока 106x130...
# Обработка блока 106x131...
# Обработка блока 106x132...
# Обработка блока 106x133...
# Обработка блока 106x134...
# Обработка блока 106x135...
# Обработка блока 106x136...
# Обработка блока 107x1...
# Обработка блока 107x2...
# Обработка блока 107x3...
# Обработка блока 107x4...
# Обработка блока 107x5...
# Обработка блока 107x6...
# Обработка блока 107x7...
# Обработка блока 107x8...
# Обработка блока 107x9...
# Обработка блока 107x10...
# Обработка блока 107x11...
# Обработка блока 107x12...
# Обработка блока 107x13...
# Обработка блока 107x14...
# Обработка блока 107x15...
# Обработка блока 107x16...
# Обработка блока 107x17...
# Обработка блока 107x18...
# Обработка блока 107x19...
# Обработка блока 107x20...
# Обработка блока 107x21...
# Обработка блока 107x22...
# Обработка блока 107x23...
# Обработка блока 107x24...
# Обработка блока 107x25...
# Обработка блока 107x26...
# Обработка блока 107x27...
# Обработка блока 107x28...
# Обработка блока 107x29...
# Обработка блока 107x30...
# Обработка блока 107x31...
# Обработка блока 107x32...
# Обработка блока 107x33...
# Обработка блока 107x34...
# Обработка блока 107x35...
# Обработка блока 107x36...
# Обработка блока 107x37...
# Обработка блока 107x38...
# Обработка блока 107x39...
# Обработка блока 107x40...
# Обработка блока 107x41...
# Обработка блока 107x42...
# Обработка блока 107x43...
# Обработка блока 107x44...
# Обработка блока 107x45...
# Обработка блока 107x46...
# Обработка блока 107x47...
# Обработка блока 107x48...
# Обработка блока 107x49...
# Обработка блока 107x50...
# Обработка блока 107x51...
# Обработка блока 107x52...
# Обработка блока 107x53...
# Обработка блока 107x54...
# Обработка блока 107x55...
# Обработка блока 107x56...
# Обработка блока 107x57...
# Обработка блока 107x58...
# Обработка блока 107x59...
# Обработка блока 107x60...
# Обработка блока 107x61...
# Обработка блока 107x62...
# Обработка блока 107x63...
# Обработка блока 107x64...
# Обработка блока 107x65...
# Обработка блока 107x66...
# Обработка блока 107x67...
# Обработка блока 107x68...
# Обработка блока 107x69...
# Обработка блока 107x70...
# Обработка блока 107x71...
# Обработка блока 107x72...
# Обработка блока 107x73...
# Обработка блока 107x74...
# Обработка блока 107x75...
# Обработка блока 107x76...
# Обработка блока 107x77...
# Обработка блока 107x78...
# Обработка блока 107x79...
# Обработка блока 107x80...
# Обработка блока 107x81...
# Обработка блока 107x82...
# Обработка блока 107x83...
# Обработка блока 107x84...
# Обработка блока 107x85...
# Обработка блока 107x86...
# Обработка блока 107x87...
# Обработка блока 107x88...
# Обработка блока 107x89...
# Обработка блока 107x90...
# Обработка блока 107x91...
# Обработка блока 107x92...
# Обработка блока 107x93...
# Обработка блока 107x94...
# Обработка блока 107x95...
# Обработка блока 107x96...
# Обработка блока 107x97...
# Обработка блока 107x98...
# Обработка блока 107x99...
# Обработка блока 107x100...
# Обработка блока 107x101...
# Обработка блока 107x102...
# Обработка блока 107x103...
# Обработка блока 107x104...
# Обработка блока 107x105...
# Обработка блока 107x106...
# Обработка блока 107x107...
# Обработка блока 107x108...
# Обработка блока 107x109...
# Обработка блока 107x110...
# Обработка блока 107x111...
# Обработка блока 107x112...
# Обработка блока 107x113...
# Обработка блока 107x114...
# Обработка блока 107x115...
# Обработка блока 107x116...
# Обработка блока 107x117...
# Обработка блока 107x118...
# Обработка блока 107x119...
# Обработка блока 107x120...
# Обработка блока 107x121...
# Обработка блока 107x122...
# Обработка блока 107x123...
# Обработка блока 107x124...
# Обработка блока 107x125...
# Обработка блока 107x126...
# Обработка блока 107x127...
# Обработка блока 107x128...
# Обработка блока 107x129...
# Обработка блока 107x130...
# Обработка блока 107x131...
# Обработка блока 107x132...
# Обработка блока 107x133...
# Обработка блока 107x134...
# Обработка блока 107x135...
# Обработка блока 107x136...
# Обработка блока 108x1...
# Обработка блока 108x2...
# Обработка блока 108x3...
# Обработка блока 108x4...
# Обработка блока 108x5...
# Обработка блока 108x6...
# Обработка блока 108x7...
# Обработка блока 108x8...
# Обработка блока 108x9...
# Обработка блока 108x10...
# Обработка блока 108x11...
# Обработка блока 108x12...
# Обработка блока 108x13...
# Обработка блока 108x14...
# Обработка блока 108x15...
# Обработка блока 108x16...
# Обработка блока 108x17...
# Обработка блока 108x18...
# Обработка блока 108x19...
# Обработка блока 108x20...
# Обработка блока 108x21...
# Обработка блока 108x22...
# Обработка блока 108x23...
# Обработка блока 108x24...
# Обработка блока 108x25...
# Обработка блока 108x26...
# Обработка блока 108x27...
# Обработка блока 108x28...
# Обработка блока 108x29...
# Обработка блока 108x30...
# Обработка блока 108x31...
# Обработка блока 108x32...
# Обработка блока 108x33...
# Обработка блока 108x34...
# Обработка блока 108x35...
# Обработка блока 108x36...
# Обработка блока 108x37...
# Обработка блока 108x38...
# Обработка блока 108x39...
# Обработка блока 108x40...
# Обработка блока 108x41...
# Обработка блока 108x42...
# Обработка блока 108x43...
# Обработка блока 108x44...
# Обработка блока 108x45...
# Обработка блока 108x46...
# Обработка блока 108x47...
# Обработка блока 108x48...
# Обработка блока 108x49...
# Обработка блока 108x50...
# Обработка блока 108x51...
# Обработка блока 108x52...
# Обработка блока 108x53...
# Обработка блока 108x54...
# Обработка блока 108x55...
# Обработка блока 108x56...
# Обработка блока 108x57...
# Обработка блока 108x58...
# Обработка блока 108x59...
# Обработка блока 108x60...
# Обработка блока 108x61...
# Обработка блока 108x62...
# Обработка блока 108x63...
# Обработка блока 108x64...
# Обработка блока 108x65...
# Обработка блока 108x66...
# Обработка блока 108x67...
# Обработка блока 108x68...
# Обработка блока 108x69...
# Обработка блока 108x70...
# Обработка блока 108x71...
# Обработка блока 108x72...
# Обработка блока 108x73...
# Обработка блока 108x74...
# Обработка блока 108x75...
# Обработка блока 108x76...
# Обработка блока 108x77...
# Обработка блока 108x78...
# Обработка блока 108x79...
# Обработка блока 108x80...
# Обработка блока 108x81...
# Обработка блока 108x82...
# Обработка блока 108x83...
# Обработка блока 108x84...
# Обработка блока 108x85...
# Обработка блока 108x86...
# Обработка блока 108x87...
# Обработка блока 108x88...
# Обработка блока 108x89...
# Обработка блока 108x90...
# Обработка блока 108x91...
# Обработка блока 108x92...
# Обработка блока 108x93...
# Обработка блока 108x94...
# Обработка блока 108x95...
# Обработка блока 108x96...
# Обработка блока 108x97...
# Обработка блока 108x98...
# Обработка блока 108x99...
# Обработка блока 108x100...
# Обработка блока 108x101...
# Обработка блока 108x102...
# Обработка блока 108x103...
# Обработка блока 108x104...
# Обработка блока 108x105...
# Обработка блока 108x106...
# Обработка блока 108x107...
# Обработка блока 108x108...
# Обработка блока 108x109...
# Обработка блока 108x110...
# Обработка блока 108x111...
# Обработка блока 108x112...
# Обработка блока 108x113...
# Обработка блока 108x114...
# Обработка блока 108x115...
# Обработка блока 108x116...
# Обработка блока 108x117...
# Обработка блока 108x118...
# Обработка блока 108x119...
# Обработка блока 108x120...
# Обработка блока 108x121...
# Обработка блока 108x122...
# Обработка блока 108x123...
# Обработка блока 108x124...
# Обработка блока 108x125...
# Обработка блока 108x126...
# Обработка блока 108x127...
# Обработка блока 108x128...
# Обработка блока 108x129...
# Обработка блока 108x130...
# Обработка блока 108x131...
# Обработка блока 108x132...
# Обработка блока 108x133...
# Обработка блока 108x134...
# Обработка блока 108x135...
# Обработка блока 108x136...
# Обработка блока 109x1...
# Обработка блока 109x2...
# Обработка блока 109x3...
# Обработка блока 109x4...
# Обработка блока 109x5...
# Обработка блока 109x6...
# Обработка блока 109x7...
# Обработка блока 109x8...
# Обработка блока 109x9...
# Обработка блока 109x10...
# Обработка блока 109x11...
# Обработка блока 109x12...
# Обработка блока 109x13...
# Обработка блока 109x14...
# Обработка блока 109x15...
# Обработка блока 109x16...
# Обработка блока 109x17...
# Обработка блока 109x18...
# Обработка блока 109x19...
# Обработка блока 109x20...
# Обработка блока 109x21...
# Обработка блока 109x22...
# Обработка блока 109x23...
# Обработка блока 109x24...
# Обработка блока 109x25...
# Обработка блока 109x26...
# Обработка блока 109x27...
# Обработка блока 109x28...
# Обработка блока 109x29...
# Обработка блока 109x30...
# Обработка блока 109x31...
# Обработка блока 109x32...
# Обработка блока 109x33...
# Обработка блока 109x34...
# Обработка блока 109x35...
# Обработка блока 109x36...
# Обработка блока 109x37...
# Обработка блока 109x38...
# Обработка блока 109x39...
# Обработка блока 109x40...
# Обработка блока 109x41...
# Обработка блока 109x42...
# Обработка блока 109x43...
# Обработка блока 109x44...
# Обработка блока 109x45...
# Обработка блока 109x46...
# Обработка блока 109x47...
# Обработка блока 109x48...
# Обработка блока 109x49...
# Обработка блока 109x50...
# Обработка блока 109x51...
# Обработка блока 109x52...
# Обработка блока 109x53...
# Обработка блока 109x54...
# Обработка блока 109x55...
# Обработка блока 109x56...
# Обработка блока 109x57...
# Обработка блока 109x58...
# Обработка блока 109x59...
# Обработка блока 109x60...
# Обработка блока 109x61...
# Обработка блока 109x62...
# Обработка блока 109x63...
# Обработка блока 109x64...
# Обработка блока 109x65...
# Обработка блока 109x66...
# Обработка блока 109x67...
# Обработка блока 109x68...
# Обработка блока 109x69...
# Обработка блока 109x70...
# Обработка блока 109x71...
# Обработка блока 109x72...
# Обработка блока 109x73...
# Обработка блока 109x74...
# Обработка блока 109x75...
# Обработка блока 109x76...
# Обработка блока 109x77...
# Обработка блока 109x78...
# Обработка блока 109x79...
# Обработка блока 109x80...
# Обработка блока 109x81...
# Обработка блока 109x82...
# Обработка блока 109x83...
# Обработка блока 109x84...
# Обработка блока 109x85...
# Обработка блока 109x86...
# Обработка блока 109x87...
# Обработка блока 109x88...
# Обработка блока 109x89...
# Обработка блока 109x90...
# Обработка блока 109x91...
# Обработка блока 109x92...
# Обработка блока 109x93...
# Обработка блока 109x94...
# Обработка блока 109x95...
# Обработка блока 109x96...
# Обработка блока 109x97...
# Обработка блока 109x98...
# Обработка блока 109x99...
# Обработка блока 109x100...
# Обработка блока 109x101...
# Обработка блока 109x102...
# Обработка блока 109x103...
# Обработка блока 109x104...
# Обработка блока 109x105...
# Обработка блока 109x106...
# Обработка блока 109x107...
# Обработка блока 109x108...
# Обработка блока 109x109...
# Обработка блока 109x110...
# Обработка блока 109x111...
# Обработка блока 109x112...
# Обработка блока 109x113...
# Обработка блока 109x114...
# Обработка блока 109x115...
# Обработка блока 109x116...
# Обработка блока 109x117...
# Обработка блока 109x118...
# Обработка блока 109x119...
# Обработка блока 109x120...
# Обработка блока 109x121...
# Обработка блока 109x122...
# Обработка блока 109x123...
# Обработка блока 109x124...
# Обработка блока 109x125...
# Обработка блока 109x126...
# Обработка блока 109x127...
# Обработка блока 109x128...
# Обработка блока 109x129...
# Обработка блока 109x130...
# Обработка блока 109x131...
# Обработка блока 109x132...
# Обработка блока 109x133...
# Обработка блока 109x134...
# Обработка блока 109x135...
# Обработка блока 109x136...
# Обработка блока 110x1...
# Обработка блока 110x2...
# Обработка блока 110x3...
# Обработка блока 110x4...
# Обработка блока 110x5...
# Обработка блока 110x6...
# Обработка блока 110x7...
# Обработка блока 110x8...
# Обработка блока 110x9...
# Обработка блока 110x10...
# Обработка блока 110x11...
# Обработка блока 110x12...
# Обработка блока 110x13...
# Обработка блока 110x14...
# Обработка блока 110x15...
# Обработка блока 110x16...
# Обработка блока 110x17...
# Обработка блока 110x18...
# Обработка блока 110x19...
# Обработка блока 110x20...
# Обработка блока 110x21...
# Обработка блока 110x22...
# Обработка блока 110x23...
# Обработка блока 110x24...
# Обработка блока 110x25...
# Обработка блока 110x26...
# Обработка блока 110x27...
# Обработка блока 110x28...
# Обработка блока 110x29...
# Обработка блока 110x30...
# Обработка блока 110x31...
# Обработка блока 110x32...
# Обработка блока 110x33...
# Обработка блока 110x34...
# Обработка блока 110x35...
# Обработка блока 110x36...
# Обработка блока 110x37...
# Обработка блока 110x38...
# Обработка блока 110x39...
# Обработка блока 110x40...
# Обработка блока 110x41...
# Обработка блока 110x42...
# Обработка блока 110x43...
# Обработка блока 110x44...
# Обработка блока 110x45...
# Обработка блока 110x46...
# Обработка блока 110x47...
# Обработка блока 110x48...
# Обработка блока 110x49...
# Обработка блока 110x50...
# Обработка блока 110x51...
# Обработка блока 110x52...
# Обработка блока 110x53...
# Обработка блока 110x54...
# Обработка блока 110x55...
# Обработка блока 110x56...
# Обработка блока 110x57...
# Обработка блока 110x58...
# Обработка блока 110x59...
# Обработка блока 110x60...
# Обработка блока 110x61...
# Обработка блока 110x62...
# Обработка блока 110x63...
# Обработка блока 110x64...
# Обработка блока 110x65...
# Обработка блока 110x66...
# Обработка блока 110x67...
# Обработка блока 110x68...
# Обработка блока 110x69...
# Обработка блока 110x70...
# Обработка блока 110x71...
# Обработка блока 110x72...
# Обработка блока 110x73...
# Обработка блока 110x74...
# Обработка блока 110x75...
# Обработка блока 110x76...
# Обработка блока 110x77...
# Обработка блока 110x78...
# Обработка блока 110x79...
# Обработка блока 110x80...
# Обработка блока 110x81...
# Обработка блока 110x82...
# Обработка блока 110x83...
# Обработка блока 110x84...
# Обработка блока 110x85...
# Обработка блока 110x86...
# Обработка блока 110x87...
# Обработка блока 110x88...
# Обработка блока 110x89...
# Обработка блока 110x90...
# Обработка блока 110x91...
# Обработка блока 110x92...
# Обработка блока 110x93...
# Обработка блока 110x94...
# Обработка блока 110x95...
# Обработка блока 110x96...
# Обработка блока 110x97...
# Обработка блока 110x98...
# Обработка блока 110x99...
# Обработка блока 110x100...
# Обработка блока 110x101...
# Обработка блока 110x102...
# Обработка блока 110x103...
# Обработка блока 110x104...
# Обработка блока 110x105...
# Обработка блока 110x106...
# Обработка блока 110x107...
# Обработка блока 110x108...
# Обработка блока 110x109...
# Обработка блока 110x110...
# Обработка блока 110x111...
# Обработка блока 110x112...
# Обработка блока 110x113...
# Обработка блока 110x114...
# Обработка блока 110x115...
# Обработка блока 110x116...
# Обработка блока 110x117...
# Обработка блока 110x118...
# Обработка блока 110x119...
# Обработка блока 110x120...
# Обработка блока 110x121...
# Обработка блока 110x122...
# Обработка блока 110x123...
# Обработка блока 110x124...
# Обработка блока 110x125...
# Обработка блока 110x126...
# Обработка блока 110x127...
# Обработка блока 110x128...
# Обработка блока 110x129...
# Обработка блока 110x130...
# Обработка блока 110x131...
# Обработка блока 110x132...
# Обработка блока 110x133...
# Обработка блока 110x134...
# Обработка блока 110x135...
# Обработка блока 110x136...
# Обработка блока 111x1...
# Обработка блока 111x2...
# Обработка блока 111x3...
# Обработка блока 111x4...
# Обработка блока 111x5...
# Обработка блока 111x6...
# Обработка блока 111x7...
# Обработка блока 111x8...
# Обработка блока 111x9...
# Обработка блока 111x10...
# Обработка блока 111x11...
# Обработка блока 111x12...
# Обработка блока 111x13...
# Обработка блока 111x14...
# Обработка блока 111x15...
# Обработка блока 111x16...
# Обработка блока 111x17...
# Обработка блока 111x18...
# Обработка блока 111x19...
# Обработка блока 111x20...
# Обработка блока 111x21...
# Обработка блока 111x22...
# Обработка блока 111x23...
# Обработка блока 111x24...
# Обработка блока 111x25...
# Обработка блока 111x26...
# Обработка блока 111x27...
# Обработка блока 111x28...
# Обработка блока 111x29...
# Обработка блока 111x30...
# Обработка блока 111x31...
# Обработка блока 111x32...
# Обработка блока 111x33...
# Обработка блока 111x34...
# Обработка блока 111x35...
# Обработка блока 111x36...
# Обработка блока 111x37...
# Обработка блока 111x38...
# Обработка блока 111x39...
# Обработка блока 111x40...
# Обработка блока 111x41...
# Обработка блока 111x42...
# Обработка блока 111x43...
# Обработка блока 111x44...
# Обработка блока 111x45...
# Обработка блока 111x46...
# Обработка блока 111x47...
# Обработка блока 111x48...
# Обработка блока 111x49...
# Обработка блока 111x50...
# Обработка блока 111x51...
# Обработка блока 111x52...
# Обработка блока 111x53...
# Обработка блока 111x54...
# Обработка блока 111x55...
# Обработка блока 111x56...
# Обработка блока 111x57...
# Обработка блока 111x58...
# Обработка блока 111x59...
# Обработка блока 111x60...
# Обработка блока 111x61...
# Обработка блока 111x62...
# Обработка блока 111x63...
# Обработка блока 111x64...
# Обработка блока 111x65...
# Обработка блока 111x66...
# Обработка блока 111x67...
# Обработка блока 111x68...
# Обработка блока 111x69...
# Обработка блока 111x70...
# Обработка блока 111x71...
# Обработка блока 111x72...
# Обработка блока 111x73...
# Обработка блока 111x74...
# Обработка блока 111x75...
# Обработка блока 111x76...
# Обработка блока 111x77...
# Обработка блока 111x78...
# Обработка блока 111x79...
# Обработка блока 111x80...
# Обработка блока 111x81...
# Обработка блока 111x82...
# Обработка блока 111x83...
# Обработка блока 111x84...
# Обработка блока 111x85...
# Обработка блока 111x86...
# Обработка блока 111x87...
# Обработка блока 111x88...
# Обработка блока 111x89...
# Обработка блока 111x90...
# Обработка блока 111x91...
# Обработка блока 111x92...
# Обработка блока 111x93...
# Обработка блока 111x94...
# Обработка блока 111x95...
# Обработка блока 111x96...
# Обработка блока 111x97...
# Обработка блока 111x98...
# Обработка блока 111x99...
# Обработка блока 111x100...
# Обработка блока 111x101...
# Обработка блока 111x102...
# Обработка блока 111x103...
# Обработка блока 111x104...
# Обработка блока 111x105...
# Обработка блока 111x106...
# Обработка блока 111x107...
# Обработка блока 111x108...
# Обработка блока 111x109...
# Обработка блока 111x110...
# Обработка блока 111x111...
# Обработка блока 111x112...
# Обработка блока 111x113...
# Обработка блока 111x114...
# Обработка блока 111x115...
# Обработка блока 111x116...
# Обработка блока 111x117...
# Обработка блока 111x118...
# Обработка блока 111x119...
# Обработка блока 111x120...
# Обработка блока 111x121...
# Обработка блока 111x122...
# Обработка блока 111x123...
# Обработка блока 111x124...
# Обработка блока 111x125...
# Обработка блока 111x126...
# Обработка блока 111x127...
# Обработка блока 111x128...
# Обработка блока 111x129...
# Обработка блока 111x130...
# Обработка блока 111x131...
# Обработка блока 111x132...
# Обработка блока 111x133...
# Обработка блока 111x134...
# Обработка блока 111x135...
# Обработка блока 111x136...
# Обработка блока 112x1...
# Обработка блока 112x2...
# Обработка блока 112x3...
# Обработка блока 112x4...
# Обработка блока 112x5...
# Обработка блока 112x6...
# Обработка блока 112x7...
# Обработка блока 112x8...
# Обработка блока 112x9...
# Обработка блока 112x10...
# Обработка блока 112x11...
# Обработка блока 112x12...
# Обработка блока 112x13...
# Обработка блока 112x14...
# Обработка блока 112x15...
# Обработка блока 112x16...
# Обработка блока 112x17...
# Обработка блока 112x18...
# Обработка блока 112x19...
# Обработка блока 112x20...
# Обработка блока 112x21...
# Обработка блока 112x22...
# Обработка блока 112x23...
# Обработка блока 112x24...
# Обработка блока 112x25...
# Обработка блока 112x26...
# Обработка блока 112x27...
# Обработка блока 112x28...
# Обработка блока 112x29...
# Обработка блока 112x30...
# Обработка блока 112x31...
# Обработка блока 112x32...
# Обработка блока 112x33...
# Обработка блока 112x34...
# Обработка блока 112x35...
# Обработка блока 112x36...
# Обработка блока 112x37...
# Обработка блока 112x38...
# Обработка блока 112x39...
# Обработка блока 112x40...
# Обработка блока 112x41...
# Обработка блока 112x42...
# Обработка блока 112x43...
# Обработка блока 112x44...
# Обработка блока 112x45...
# Обработка блока 112x46...
# Обработка блока 112x47...
# Обработка блока 112x48...
# Обработка блока 112x49...
# Обработка блока 112x50...
# Обработка блока 112x51...
# Обработка блока 112x52...
# Обработка блока 112x53...
# Обработка блока 112x54...
# Обработка блока 112x55...
# Обработка блока 112x56...
# Обработка блока 112x57...
# Обработка блока 112x58...
# Обработка блока 112x59...
# Обработка блока 112x60...
# Обработка блока 112x61...
# Обработка блока 112x62...
# Обработка блока 112x63...
# Обработка блока 112x64...
# Обработка блока 112x65...
# Обработка блока 112x66...
# Обработка блока 112x67...
# Обработка блока 112x68...
# Обработка блока 112x69...
# Обработка блока 112x70...
# Обработка блока 112x71...
# Обработка блока 112x72...
# Обработка блока 112x73...
# Обработка блока 112x74...
# Обработка блока 112x75...
# Обработка блока 112x76...
# Обработка блока 112x77...
# Обработка блока 112x78...
# Обработка блока 112x79...
# Обработка блока 112x80...
# Обработка блока 112x81...
# Обработка блока 112x82...
# Обработка блока 112x83...
# Обработка блока 112x84...
# Обработка блока 112x85...
# Обработка блока 112x86...
# Обработка блока 112x87...
# Обработка блока 112x88...
# Обработка блока 112x89...
# Обработка блока 112x90...
# Обработка блока 112x91...
# Обработка блока 112x92...
# Обработка блока 112x93...
# Обработка блока 112x94...
# Обработка блока 112x95...
# Обработка блока 112x96...
# Обработка блока 112x97...
# Обработка блока 112x98...
# Обработка блока 112x99...
# Обработка блока 112x100...
# Обработка блока 112x101...
# Обработка блока 112x102...
# Обработка блока 112x103...
# Обработка блока 112x104...
# Обработка блока 112x105...
# Обработка блока 112x106...
# Обработка блока 112x107...
# Обработка блока 112x108...
# Обработка блока 112x109...
# Обработка блока 112x110...
# Обработка блока 112x111...
# Обработка блока 112x112...
# Обработка блока 112x113...
# Обработка блока 112x114...
# Обработка блока 112x115...
# Обработка блока 112x116...
# Обработка блока 112x117...
# Обработка блока 112x118...
# Обработка блока 112x119...
# Обработка блока 112x120...
# Обработка блока 112x121...
# Обработка блока 112x122...
# Обработка блока 112x123...
# Обработка блока 112x124...
# Обработка блока 112x125...
# Обработка блока 112x126...
# Обработка блока 112x127...
# Обработка блока 112x128...
# Обработка блока 112x129...
# Обработка блока 112x130...
# Обработка блока 112x131...
# Обработка блока 112x132...
# Обработка блока 112x133...
# Обработка блока 112x134...
# Обработка блока 112x135...
# Обработка блока 112x136...
# Обработка блока 113x1...
# Обработка блока 113x2...
# Обработка блока 113x3...
# Обработка блока 113x4...
# Обработка блока 113x5...
# Обработка блока 113x6...
# Обработка блока 113x7...
# Обработка блока 113x8...
# Обработка блока 113x9...
# Обработка блока 113x10...
# Обработка блока 113x11...
# Обработка блока 113x12...
# Обработка блока 113x13...
# Обработка блока 113x14...
# Обработка блока 113x15...
# Обработка блока 113x16...
# Обработка блока 113x17...
# Обработка блока 113x18...
# Обработка блока 113x19...
# Обработка блока 113x20...
# Обработка блока 113x21...
# Обработка блока 113x22...
# Обработка блока 113x23...
# Обработка блока 113x24...
# Обработка блока 113x25...
# Обработка блока 113x26...
# Обработка блока 113x27...
# Обработка блока 113x28...
# Обработка блока 113x29...
# Обработка блока 113x30...
# Обработка блока 113x31...
# Обработка блока 113x32...
# Обработка блока 113x33...
# Обработка блока 113x34...
# Обработка блока 113x35...
# Обработка блока 113x36...
# Обработка блока 113x37...
# Обработка блока 113x38...
# Обработка блока 113x39...
# Обработка блока 113x40...
# Обработка блока 113x41...
# Обработка блока 113x42...
# Обработка блока 113x43...
# Обработка блока 113x44...
# Обработка блока 113x45...
# Обработка блока 113x46...
# Обработка блока 113x47...
# Обработка блока 113x48...
# Обработка блока 113x49...
# Обработка блока 113x50...
# Обработка блока 113x51...
# Обработка блока 113x52...
# Обработка блока 113x53...
# Обработка блока 113x54...
# Обработка блока 113x55...
# Обработка блока 113x56...
# Обработка блока 113x57...
# Обработка блока 113x58...
# Обработка блока 113x59...
# Обработка блока 113x60...
# Обработка блока 113x61...
# Обработка блока 113x62...
# Обработка блока 113x63...
# Обработка блока 113x64...
# Обработка блока 113x65...
# Обработка блока 113x66...
# Обработка блока 113x67...
# Обработка блока 113x68...
# Обработка блока 113x69...
# Обработка блока 113x70...
# Обработка блока 113x71...
# Обработка блока 113x72...
# Обработка блока 113x73...
# Обработка блока 113x74...
# Обработка блока 113x75...
# Обработка блока 113x76...
# Обработка блока 113x77...
# Обработка блока 113x78...
# Обработка блока 113x79...
# Обработка блока 113x80...
# Обработка блока 113x81...
# Обработка блока 113x82...
# Обработка блока 113x83...
# Обработка блока 113x84...
# Обработка блока 113x85...
# Обработка блока 113x86...
# Обработка блока 113x87...
# Обработка блока 113x88...
# Обработка блока 113x89...
# Обработка блока 113x90...
# Обработка блока 113x91...
# Обработка блока 113x92...
# Обработка блока 113x93...
# ...
# Обработка блока 132x72...
# Обработка блока 132x73...
# Обработка блока 132x74...
# Обработка блока 132x75...
# Обработка блока 132x76...
# Обработка блока 132x77...
# Обработка блока 132x78...
# Обработка блока 132x79...
# Обработка блока 132x80...
# Обработка блока 132x81...
# Обработка блока 132x82...
# Обработка блока 132x83...
# Обработка блока 132x84...
# Обработка блока 132x85...
# Обработка блока 132x86...
# Обработка блока 132x87...
# Обработка блока 132x88...
# Обработка блока 132x89...
# Обработка блока 132x90...
# Обработка блока 132x91...
# Обработка блока 132x92...
# Обработка блока 132x93...
# Обработка блока 132x94...
# Обработка блока 132x95...
# Обработка блока 132x96...
# Обработка блока 132x97...
# Обработка блока 132x98...
# Обработка блока 132x99...
# Обработка блока 132x100...
# Обработка блока 132x101...
# Обработка блока 132x102...
# Обработка блока 132x103...
# Обработка блока 132x104...
# Обработка блока 132x105...
# Обработка блока 132x106...
# Обработка блока 132x107...
# Обработка блока 132x108...
# Обработка блока 132x109...
# Обработка блока 132x110...
# Обработка блока 132x111...
# Обработка блока 132x112...
# Обработка блока 132x113...
# Обработка блока 132x114...
# Обработка блока 132x115...
# Обработка блока 132x116...
# Обработка блока 132x117...
# Обработка блока 132x118...
# Обработка блока 132x119...
# Обработка блока 132x120...
# Обработка блока 132x121...
# Обработка блока 132x122...
# Обработка блока 132x123...
# Обработка блока 132x124...
# Обработка блока 132x125...
# Обработка блока 132x126...
# Обработка блока 132x127...
# Обработка блока 132x128...
# Обработка блока 132x129...
# Обработка блока 132x130...
# Обработка блока 132x131...
# Обработка блока 132x132...
# Обработка блока 132x133...
# Обработка блока 132x134...
# Обработка блока 132x135...
# Обработка блока 132x136...
# Обработка блока 133x1...
# Обработка блока 133x2...
# Обработка блока 133x3...
# Обработка блока 133x4...
# Обработка блока 133x5...
# Обработка блока 133x6...
# Обработка блока 133x7...
# Обработка блока 133x8...
# Обработка блока 133x9...
# Обработка блока 133x10...
# Обработка блока 133x11...
# Обработка блока 133x12...
# Обработка блока 133x13...
# Обработка блока 133x14...
# Обработка блока 133x15...
# Обработка блока 133x16...
# Обработка блока 133x17...
# Обработка блока 133x18...
# Обработка блока 133x19...
# Обработка блока 133x20...
# Обработка блока 133x21...
# Обработка блока 133x22...
# Обработка блока 133x23...
# Обработка блока 133x24...
# Обработка блока 133x25...
# Обработка блока 133x26...
# Обработка блока 133x27...
# Обработка блока 133x28...
# Обработка блока 133x29...
# Обработка блока 133x30...
# Обработка блока 133x31...
# Обработка блока 133x32...
# Обработка блока 133x33...
# Обработка блока 133x34...
# Обработка блока 133x35...
# Обработка блока 133x36...
# Обработка блока 133x37...
# Обработка блока 133x38...
# Обработка блока 133x39...
# Обработка блока 133x40...
# Обработка блока 133x41...
# Обработка блока 133x42...
# Обработка блока 133x43...
# Обработка блока 133x44...
# Обработка блока 133x45...
# Обработка блока 133x46...
# Обработка блока 133x47...
# Обработка блока 133x48...
# Обработка блока 133x49...
# Обработка блока 133x50...
# Обработка блока 133x51...
# Обработка блока 133x52...
# Обработка блока 133x53...
# Обработка блока 133x54...
# Обработка блока 133x55...
# Обработка блока 133x56...
# Обработка блока 133x57...
# Обработка блока 133x58...
# Обработка блока 133x59...
# Обработка блока 133x60...
# Обработка блока 133x61...
# Обработка блока 133x62...
# Обработка блока 133x63...
# Обработка блока 133x64...
# Обработка блока 133x65...
# Обработка блока 133x66...
# Обработка блока 133x67...
# Обработка блока 133x68...
# Обработка блока 133x69...
# Обработка блока 133x70...
# Обработка блока 133x71...
# Обработка блока 133x72...
# Обработка блока 133x73...
# Обработка блока 133x74...
# Обработка блока 133x75...
# Обработка блока 133x76...
# Обработка блока 133x77...
# Обработка блока 133x78...
# Обработка блока 133x79...
# Обработка блока 133x80...
# Обработка блока 133x81...
# Обработка блока 133x82...
# Обработка блока 133x83...
# Обработка блока 133x84...
# Обработка блока 133x85...
# Обработка блока 133x86...
# Обработка блока 133x87...
# Обработка блока 133x88...
# Обработка блока 133x89...
# Обработка блока 133x90...
# Обработка блока 133x91...
# Обработка блока 133x92...
# Обработка блока 133x93...
# Обработка блока 133x94...
# Обработка блока 133x95...
# Обработка блока 133x96...
# Обработка блока 133x97...
# Обработка блока 133x98...
# Обработка блока 133x99...
# Обработка блока 133x100...
# Обработка блока 133x101...
# Обработка блока 133x102...
# Обработка блока 133x103...
# Обработка блока 133x104...
# Обработка блока 133x105...
# Обработка блока 133x106...
# Обработка блока 133x107...
# Обработка блока 133x108...
# Обработка блока 133x109...
# Обработка блока 133x110...
# Обработка блока 133x111...
# Обработка блока 133x112...
# Обработка блока 133x113...
# Обработка блока 133x114...
# Обработка блока 133x115...
# Обработка блока 133x116...
# Обработка блока 133x117...
# Обработка блока 133x118...
# Обработка блока 133x119...
# Обработка блока 133x120...
# Обработка блока 133x121...
# Обработка блока 133x122...
# Обработка блока 133x123...
# Обработка блока 133x124...
# Обработка блока 133x125...
# Обработка блока 133x126...
# Обработка блока 133x127...
# Обработка блока 133x128...
# Обработка блока 133x129...
# Обработка блока 133x130...
# Обработка блока 133x131...
# Обработка блока 133x132...
# Обработка блока 133x133...
# Обработка блока 133x134...
# Обработка блока 133x135...
# Обработка блока 133x136...
# Обработка блока 134x1...
# Обработка блока 134x2...
# Обработка блока 134x3...
# Обработка блока 134x4...
# Обработка блока 134x5...
# Обработка блока 134x6...
# Обработка блока 134x7...
# Обработка блока 134x8...
# Обработка блока 134x9...
# Обработка блока 134x10...
# Обработка блока 134x11...
# Обработка блока 134x12...
# Обработка блока 134x13...
# Обработка блока 134x14...
# Обработка блока 134x15...
# Обработка блока 134x16...
# Обработка блока 134x17...
# Обработка блока 134x18...
# Обработка блока 134x19...
# Обработка блока 134x20...
# Обработка блока 134x21...
# Обработка блока 134x22...
# Обработка блока 134x23...
# Обработка блока 134x24...
# Обработка блока 134x25...
# Обработка блока 134x26...
# Обработка блока 134x27...
# Обработка блока 134x28...
# Обработка блока 134x29...
# Обработка блока 134x30...
# Обработка блока 134x31...
# Обработка блока 134x32...
# Обработка блока 134x33...
# Обработка блока 134x34...
# Обработка блока 134x35...
# Обработка блока 134x36...
# Обработка блока 134x37...
# Обработка блока 134x38...
# Обработка блока 134x39...
# Обработка блока 134x40...
# Обработка блока 134x41...
# Обработка блока 134x42...
# Обработка блока 134x43...
# Обработка блока 134x44...
# Обработка блока 134x45...
# Обработка блока 134x46...
# Обработка блока 134x47...
# Обработка блока 134x48...
# Обработка блока 134x49...
# Обработка блока 134x50...
# Обработка блока 134x51...
# Обработка блока 134x52...
# Обработка блока 134x53...
# Обработка блока 134x54...
# Обработка блока 134x55...
# Обработка блока 134x56...
# Обработка блока 134x57...
# Обработка блока 134x58...
# Обработка блока 134x59...
# Обработка блока 134x60...
# Обработка блока 134x61...
# Обработка блока 134x62...
# Обработка блока 134x63...
# Обработка блока 134x64...
# Обработка блока 134x65...
# Обработка блока 134x66...
# Обработка блока 134x67...
# Обработка блока 134x68...
# Обработка блока 134x69...
# Обработка блока 134x70...
# Обработка блока 134x71...
# Обработка блока 134x72...
# Обработка блока 134x73...
# Обработка блока 134x74...
# Обработка блока 134x75...
# Обработка блока 134x76...
# Обработка блока 134x77...
# Обработка блока 134x78...
# Обработка блока 134x79...
# Обработка блока 134x80...
# Обработка блока 134x81...
# Обработка блока 134x82...
# Обработка блока 134x83...
# Обработка блока 134x84...
# Обработка блока 134x85...
# Обработка блока 134x86...
# Обработка блока 134x87...
# Обработка блока 134x88...
# Обработка блока 134x89...
# Обработка блока 134x90...
# Обработка блока 134x91...
# Обработка блока 134x92...
# Обработка блока 134x93...
# Обработка блока 134x94...
# Обработка блока 134x95...
# Обработка блока 134x96...
# Обработка блока 134x97...
# Обработка блока 134x98...
# Обработка блока 134x99...
# Обработка блока 134x100...
# Обработка блока 134x101...
# Обработка блока 134x102...
# Обработка блока 134x103...
# Обработка блока 134x104...
# Обработка блока 134x105...
# Обработка блока 134x106...
# Обработка блока 134x107...
# Обработка блока 134x108...
# Обработка блока 134x109...
# Обработка блока 134x110...
# Обработка блока 134x111...
# Обработка блока 134x112...
# Обработка блока 134x113...
# Обработка блока 134x114...
# Обработка блока 134x115...
# Обработка блока 134x116...
# Обработка блока 134x117...
# Обработка блока 134x118...
# Обработка блока 134x119...
# Обработка блока 134x120...
# Обработка блока 134x121...
# Обработка блока 134x122...
# Обработка блока 134x123...
# Обработка блока 134x124...
# Обработка блока 134x125...
# Обработка блока 134x126...
# Обработка блока 134x127...
# Обработка блока 134x128...
# Обработка блока 134x129...
# Обработка блока 134x130...
# Обработка блока 134x131...
# Обработка блока 134x132...
# Обработка блока 134x133...
# Обработка блока 134x134...
# Обработка блока 134x135...
# Обработка блока 134x136...
# Обработка блока 135x1...
# Обработка блока 135x2...
# Обработка блока 135x3...
# Обработка блока 135x4...
# Обработка блока 135x5...
# Обработка блока 135x6...
# Обработка блока 135x7...
# Обработка блока 135x8...
# Обработка блока 135x9...
# Обработка блока 135x10...
# Обработка блока 135x11...
# Обработка блока 135x12...
# Обработка блока 135x13...
# Обработка блока 135x14...
# Обработка блока 135x15...
# Обработка блока 135x16...
# Обработка блока 135x17...
# Обработка блока 135x18...
# Обработка блока 135x19...
# Обработка блока 135x20...
# Обработка блока 135x21...
# Обработка блока 135x22...
# Обработка блока 135x23...
# Обработка блока 135x24...
# Обработка блока 135x25...
# Обработка блока 135x26...
# Обработка блока 135x27...
# Обработка блока 135x28...
# Обработка блока 135x29...
# Обработка блока 135x30...
# Обработка блока 135x31...
# Обработка блока 135x32...
# Обработка блока 135x33...
# Обработка блока 135x34...
# Обработка блока 135x35...
# Обработка блока 135x36...
# Обработка блока 135x37...
# Обработка блока 135x38...
# Обработка блока 135x39...
# Обработка блока 135x40...
# Обработка блока 135x41...
# Обработка блока 135x42...
# Обработка блока 135x43...
# Обработка блока 135x44...
# Обработка блока 135x45...
# Обработка блока 135x46...
# Обработка блока 135x47...
# Обработка блока 135x48...
# Обработка блока 135x49...
# Обработка блока 135x50...
# Обработка блока 135x51...
# Обработка блока 135x52...
# Обработка блока 135x53...
# Обработка блока 135x54...
# Обработка блока 135x55...
# Обработка блока 135x56...
# Обработка блока 135x57...
# Обработка блока 135x58...
# Обработка блока 135x59...
# Обработка блока 135x60...
# Обработка блока 135x61...
# Обработка блока 135x62...
# Обработка блока 135x63...
# Обработка блока 135x64...
# Обработка блока 135x65...
# Обработка блока 135x66...
# Обработка блока 135x67...
# Обработка блока 135x68...
# Обработка блока 135x69...
# Обработка блока 135x70...
# Обработка блока 135x71...
# Обработка блока 135x72...
# Обработка блока 135x73...
# Обработка блока 135x74...
# Обработка блока 135x75...
# Обработка блока 135x76...
# Обработка блока 135x77...
# Обработка блока 135x78...
# Обработка блока 135x79...
# Обработка блока 135x80...
# Обработка блока 135x81...
# Обработка блока 135x82...
# Обработка блока 135x83...
# Обработка блока 135x84...
# Обработка блока 135x85...
# Обработка блока 135x86...
# Обработка блока 135x87...
# Обработка блока 135x88...
# Обработка блока 135x89...
# Обработка блока 135x90...
# Обработка блока 135x91...
# Обработка блока 135x92...
# Обработка блока 135x93...
# Обработка блока 135x94...
# Обработка блока 135x95...
# Обработка блока 135x96...
# Обработка блока 135x97...
# Обработка блока 135x98...
# Обработка блока 135x99...
# Обработка блока 135x100...
# Обработка блока 135x101...
# Обработка блока 135x102...
# Обработка блока 135x103...
# Обработка блока 135x104...
# Обработка блока 135x105...
# Обработка блока 135x106...
# Обработка блока 135x107...
# Обработка блока 135x108...
# Обработка блока 135x109...
# Обработка блока 135x110...
# Обработка блока 135x111...
# Обработка блока 135x112...
# Обработка блока 135x113...
# Обработка блока 135x114...
# Обработка блока 135x115...
# Обработка блока 135x116...
# Обработка блока 135x117...
# Обработка блока 135x118...
# Обработка блока 135x119...
# Обработка блока 135x120...
# Обработка блока 135x121...
# Обработка блока 135x122...
# Обработка блока 135x123...
# Обработка блока 135x124...
# Обработка блока 135x125...
# Обработка блока 135x126...
# Обработка блока 135x127...
# Обработка блока 135x128...
# Обработка блока 135x129...
# Обработка блока 135x130...
# Обработка блока 135x131...
# Обработка блока 135x132...
# Обработка блока 135x133...
# Обработка блока 135x134...
# Обработка блока 135x135...
# Обработка блока 135x136...
# Обработка блока 136x1...
# Обработка блока 136x2...
# Обработка блока 136x3...
# Обработка блока 136x4...
# Обработка блока 136x5...
# Обработка блока 136x6...
# Обработка блока 136x7...
# Обработка блока 136x8...
# Обработка блока 136x9...
# Обработка блока 136x10...
# Обработка блока 136x11...
# Обработка блока 136x12...
# Обработка блока 136x13...
# Обработка блока 136x14...
# Обработка блока 136x15...
# Обработка блока 136x16...
# Обработка блока 136x17...
# Обработка блока 136x18...
# Обработка блока 136x19...
# Обработка блока 136x20...
# Обработка блока 136x21...
# Обработка блока 136x22...
# Обработка блока 136x23...
# Обработка блока 136x24...
# Обработка блока 136x25...
# Обработка блока 136x26...
# Обработка блока 136x27...
# Обработка блока 136x28...
# Обработка блока 136x29...
# Обработка блока 136x30...
# Обработка блока 136x31...
# Обработка блока 136x32...
# Обработка блока 136x33...
# Обработка блока 136x34...
# Обработка блока 136x35...
# Обработка блока 136x36...
# Обработка блока 136x37...
# Обработка блока 136x38...
# Обработка блока 136x39...
# Обработка блока 136x40...
# Обработка блока 136x41...
# Обработка блока 136x42...
# Обработка блока 136x43...
# Обработка блока 136x44...
# Обработка блока 136x45...
# Обработка блока 136x46...
# Обработка блока 136x47...
# Обработка блока 136x48...
# Обработка блока 136x49...
# Обработка блока 136x50...
# Обработка блока 136x51...
# Обработка блока 136x52...
# Обработка блока 136x53...
# Обработка блока 136x54...
# Обработка блока 136x55...
# Обработка блока 136x56...
# Обработка блока 136x57...
# Обработка блока 136x58...
# Обработка блока 136x59...
# Обработка блока 136x60...
# Обработка блока 136x61...
# Обработка блока 136x62...
# Обработка блока 136x63...
# Обработка блока 136x64...
# Обработка блока 136x65...
# Обработка блока 136x66...
# Обработка блока 136x67...
# Обработка блока 136x68...
# Обработка блока 136x69...
# Обработка блока 136x70...
# Обработка блока 136x71...
# Обработка блока 136x72...
# Обработка блока 136x73...
# Обработка блока 136x74...
# Обработка блока 136x75...
# Обработка блока 136x76...
# Обработка блока 136x77...
# Обработка блока 136x78...
# Обработка блока 136x79...
# Обработка блока 136x80...
# Обработка блока 136x81...
# Обработка блока 136x82...
# Обработка блока 136x83...
# Обработка блока 136x84...
# Обработка блока 136x85...
# Обработка блока 136x86...
# Обработка блока 136x87...
# Обработка блока 136x88...
# Обработка блока 136x89...
# Обработка блока 136x90...
# Обработка блока 136x91...
# Обработка блока 136x92...
# Обработка блока 136x93...
# Обработка блока 136x94...
# Обработка блока 136x95...
# Обработка блока 136x96...
# Обработка блока 136x97...
# Обработка блока 136x98...
# Обработка блока 136x99...
# Обработка блока 136x100...
# Обработка блока 136x101...
# Обработка блока 136x102...
# Обработка блока 136x103...
# Обработка блока 136x104...
# Обработка блока 136x105...
# Обработка блока 136x106...
# Обработка блока 136x107...
# Обработка блока 136x108...
# Обработка блока 136x109...
# Обработка блока 136x110...
# Обработка блока 136x111...
# Обработка блока 136x112...
# Обработка блока 136x113...
# Обработка блока 136x114...
# Обработка блока 136x115...
# Обработка блока 136x116...
# Обработка блока 136x117...
# Обработка блока 136x118...
# Обработка блока 136x119...
# Обработка блока 136x120...
# Обработка блока 136x121...
# Обработка блока 136x122...
# Обработка блока 136x123...
# Обработка блока 136x124...
# Обработка блока 136x125...
# Обработка блока 136x126...
# Обработка блока 136x127...
# Обработка блока 136x128...
# Обработка блока 136x129...
# Обработка блока 136x130...
# Обработка блока 136x131...
# Обработка блока 136x132...
# Обработка блока 136x133...
# Обработка блока 136x134...
# Обработка блока 136x135...
# Обработка блока 136x136...

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import save_npz
import numpy as np
import pickle
from google.colab import files
from tqdm import tqdm
import time
from sklearn.preprocessing import normalize

# Инициализация таймера
start_global = time.time()

# Загружаем датасет с прогресс-баром
print("1. Загрузка датасета...")
start = time.time()
books = pd.read_csv('clean_books.csv')
print(f"Загружено {len(books)} книг за {time.time() - start:.2f} секунд")

# Инициализация TF-IDF
print("\n2. Инициализация TF-IDF векторизатора...")
tfidf = TfidfVectorizer(
    stop_words='english',
    ngram_range=(1, 1),
    max_features=10000,
    dtype=np.float32
)

# Создание TF-IDF матрицы с прогресс-баром
print("\n3. Создание TF-IDF матрицы...")
start = time.time()
tfidf_matrix = tfidf.fit_transform(tqdm(books['title'].fillna(''), desc="Обработка текстов"))
print(f"TF-IDF матрица создана за {time.time() - start:.2f} секунд")
print(f"Размер матрицы: {tfidf_matrix.shape} (книги x фичи)")

# Сохранение модели TF-IDF
print("\n4. Сохранение артефактов TF-IDF...")
start = time.time()
with open('tfidf_vectorizer.pkl', 'wb') as f:
    pickle.dump(tfidf, f)
save_npz('tfidf_matrix.npz', tfidf_matrix)
print(f"Артефакты сохранены за {time.time() - start:.2f} секунд")

# Параметры для топ-рекомендаций
top_k = 5
n_books = len(books)
chunk_size = 20000

# Матрицы для хранения рекомендаций
top_indices = np.zeros((n_books, top_k), dtype=np.int32)
top_scores = np.zeros((n_books, top_k), dtype=np.float32)

# Вычисляем рекомендации по чанкам с прогресс-баром
print(f"\n5. Вычисление топ-{top_k} рекомендаций для {n_books} книг...")
total_chunks = (n_books + chunk_size - 1) // chunk_size

for i in tqdm(range(0, n_books, chunk_size), desc="Обработка чанков", total=total_chunks):
    chunk_start = i
    chunk_end = min(i + chunk_size, n_books)

    # Вычисляем схожесть для текущего чанка
    chunk_sim = cosine_similarity(tfidf_matrix[chunk_start:chunk_end], tfidf_matrix)

    # Обрабатываем каждую книгу в чанке
    for k in tqdm(range(chunk_sim.shape[0]), desc=f"Книги {chunk_start}-{chunk_end}", leave=False):
        book_idx = i + k
        sim_scores = chunk_sim[k]
        sim_scores[book_idx] = -1  # Исключаем текущую книгу

        # Находим топ-рекомендации
        top_5_indices = np.argpartition(sim_scores, -top_k)[-top_k:]
        top_5_scores = sim_scores[top_5_indices]

        # Сортируем
        sorted_indices = np.argsort(-top_5_scores)
        top_indices[book_idx] = top_5_indices[sorted_indices]
        top_scores[book_idx] = top_5_scores[sorted_indices]

# Сохранение результатов
print("\n6. Сохранение результатов...")
start = time.time()
np.save('top_5_indices.npy', top_indices)
np.save('top_5_scores.npy', top_scores)
print(f"Результаты сохранены за {time.time() - start:.2f} секунд")

# Сохранение метаданных
print("\n7. Сохранение метаданных...")
start = time.time()
book_indices = pd.Series(books.index, index=books['title'].str.lower()).to_dict()
with open('book_indices.pkl', 'wb') as f:
    pickle.dump(book_indices, f)
print(f"Метаданные сохранены за {time.time() - start:.2f} секунд")

# Итоговая информация
total_time = time.time() - start_global
print("\n" + "="*50)
print("Все компоненты успешно сохранены!")
print(f"Общее время выполнения: {total_time/60:.2f} минут")
print(f"Размер полной матрицы схожести: {n_books}x{n_books} = {n_books**2:,} элементов")
print(f"Размер сохраненных данных: {n_books}x{top_k} x2 = {n_books*top_k*2:,} элементов")
print("="*50)

# Опционально: скачиваем файлы
# print("\n8. Скачивание файлов...")
# files.download('top_5_indices.npy')
# files.download('top_5_scores.npy')
# files.download('book_indices.pkl')
# files.download('tfidf_vectorizer.pkl')
# files.download('tfidf_matrix.npz')

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from scipy.sparse import save_npz, csr_matrix
import numpy as np
import pickle
from joblib import Parallel, delayed
from tqdm import tqdm
import time

# Оптимизированная функция обработки книги
def process_book(args):
    """Обработка одной книги с распаковкой аргументов"""
    k, chunk_sim, i, top_k = args
    book_idx = i + k
    sim_scores = chunk_sim[k].copy()
    sim_scores[book_idx] = -1
    top_indices = np.argpartition(sim_scores, -top_k)[-top_k:]
    top_scores = sim_scores[top_indices]
    sorted_indices = np.argsort(-top_scores)
    return book_idx, top_indices[sorted_indices], top_scores[sorted_indices]

# Основной код
start_global = time.time()

# 1. Загрузка данных
print("1. Загрузка датасета...")
books = pd.read_csv('clean_books.csv')

# 2. TF-IDF с оптимизированными параметрами
print("\n2. Создание TF-IDF матрицы...")
tfidf = TfidfVectorizer(
    stop_words='english',
    ngram_range=(1, 1),
    max_features=5000,
    dtype=np.float32
)
tfidf_matrix = tfidf.fit_transform(books['title'].fillna(''))
tfidf_matrix = csr_matrix(tfidf_matrix, dtype=np.float32)

# 3. Сохранение моделей
with open('tfidf_vectorizer.pkl', 'wb') as f:
    pickle.dump(tfidf, f)
save_npz('tfidf_matrix.npz', tfidf_matrix)

# 4. Параметры
top_k = 5
n_books = len(books)
chunk_size = 20000
top_indices = np.zeros((n_books, top_k), dtype=np.int32)
top_scores = np.zeros((n_books, top_k), dtype=np.float32)

# 5. Основной цикл с параллельной обработкой
print(f"\n3. Вычисление рекомендаций для {n_books} книг...")
for i in tqdm(range(0, n_books, chunk_size), desc="Чанки"):
    chunk_end = min(i + chunk_size, n_books)
    chunk_sim = linear_kernel(tfidf_matrix[i:chunk_end], tfidf_matrix)

    # Подготовка аргументов для параллельной обработки
    args_list = [(k, chunk_sim, i, top_k) for k in range(chunk_sim.shape[0])]

    # Параллельная обработка с обработкой ошибок
    try:
        results = Parallel(n_jobs=-1, verbose=0)(
            delayed(process_book)(args) for args in args_list
        )

        for book_idx, indices, scores in results:
            top_indices[book_idx] = indices
            top_scores[book_idx] = scores

    except Exception as e:
        print(f"\nОшибка при обработке чанка {i}-{chunk_end}: {str(e)}")
        # Альтернативная обработка без параллелизма при ошибке
        for k in range(chunk_sim.shape[0]):
            book_idx = i + k
            sim_scores = chunk_sim[k].copy()
            sim_scores[book_idx] = -1
            top_5_indices = np.argpartition(sim_scores, -top_k)[-top_k:]
            top_5_scores = sim_scores[top_5_indices]
            sorted_indices = np.argsort(-top_5_scores)
            top_indices[book_idx] = top_5_indices[sorted_indices]
            top_scores[book_idx] = top_5_scores[sorted_indices]

# 6. Сохранение результатов
print("\n4. Сохранение результатов...")
np.save('top_5_indices.npy', top_indices)
np.save('top_5_scores.npy', top_scores)

# Сохранение метаданных
book_indices = pd.Series(books.index, index=books['title'].str.lower()).to_dict()
with open('book_indices.pkl', 'wb') as f:
    pickle.dump(book_indices, f)

# Вывод времени выполнения
total_time = (time.time()-start_global)/60
print(f"\nГотово! Общее время: {total_time:.1f} минут")
print(f"Обработано {n_books} книг")
print(f"Средняя скорость: {n_books/total_time/60:.1f} книг/сек")
# Out:
# 1. Загрузка датасета...
#
# 2. Создание TF-IDF матрицы...
#
# 3. Вычисление рекомендаций для 271379 книг...
# Чанки: 100%|██████████| 14/14 [19:39<00:00, 84.23s/it]
# 4. Сохранение результатов...
#
# Готово! Общее время: 19.7 минут
# Обработано 271379 книг
# Средняя скорость: 229.4 книг/сек

# %%
import pandas as pd
import numpy as np
from scipy.sparse import load_npz
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

class ContentRecommender:
    def __init__(self,
                 books_path='clean_books.csv',
                 tfidf_vectorizer_path='tfidf_vectorizer.pkl',
                 tfidf_matrix_path='tfidf_matrix.npz',
                 top_indices_path='top_5_indices.npy',
                 top_scores_path='top_5_scores.npy',
                 book_indices_path='book_indices.pkl'):

        # Загрузка данных с обработкой дубликатов
        self.books = pd.read_csv(books_path).drop_duplicates(subset=['title'])

        # Загрузка моделей с обработкой версий
        try:
            with open(tfidf_vectorizer_path, 'rb') as f:
                self.vectorizer = pickle.load(f)
        except Exception as e:
            print(f"Ошибка загрузки векторайзера: {e}. Инициализируем новый.")
            self.vectorizer = TfidfVectorizer(stop_words='english', ngram_range=(1, 2))

        self.tfidf_matrix = load_npz(tfidf_matrix_path)
        self.top_indices = np.load(top_indices_path)
        self.top_scores = np.load(top_scores_path)

        with open(book_indices_path, 'rb') as f:
            self.book_indices = pickle.load(f)

    def get_recommendations(self, book_title, top_n=5):
        book_title_lower = book_title.lower()

        if book_title_lower not in self.book_indices:
            return f"Книга '{book_title}' не найдена."

        idx = self.book_indices[book_title_lower]
        recommended_indices = self.top_indices[idx][:top_n]
        recommended_scores = self.top_scores[idx][:top_n]

        recommendations = self.books.iloc[recommended_indices][['title', 'author', 'year']]
        recommendations['similarity'] = recommended_scores

        # Удаление дубликатов и самой книги из рекомендаций
        recommendations = recommendations[
            (recommendations['title'].str.lower() != book_title_lower)
        ].drop_duplicates(subset=['title'])

        return recommendations.reset_index(drop=True)

if __name__ == '__main__':
    recommender = ContentRecommender()
    test_books = [
        "Harry Potter and the Sorcerer's Stone",
        "The Great Gatsby",
        "Nonexistent Book"
    ]

    for book in test_books:
        print(f"\nРекомендации для '{book}':")
        recs = recommender.get_recommendations(book)
        print(recs if isinstance(recs, pd.DataFrame) else recs)
# Out:
# Рекомендации для 'Harry Potter and the Sorcerer's Stone':
#                                                title                author  \
# 0                                   Scheme of Things     R., Barri Flowers
# 1                     Spellbound (Harlequin Romance)          Margaret Way
# 2  The Okinawa Program: How the World's Longest-L...    Bradley J. Willcox
# 3  Essential Calculus: With Applications (Dover B...  Richard A. Silverman
# 4                                   One Lonely Night         Susan Kay Law
#
#    year  similarity
# 0  2002    1.000000
# 1  1983    1.000000
# 2  2001    0.969923
# 3  1989    0.969923
# 4  1997    0.969923
#
# Рекомендации для 'The Great Gatsby':
#                                                title  \
# 0                              The Work of Her Hands
# 1  Clay's Quilt: A Novel (Ballantine Reader's Cir...
# 2  Fearless Jones (Fearless Jones Novels (Paperba...
# 3                Never Alone (Love Inspired , No 30)
# 4  Field Guide to the Birds of North America, 3rd...
#
#                         author  year  similarity
# 0                 Anne Knowles  1983         1.0
# 1                  Silas House  2002         1.0
# 2                Walter Mosley  2002         1.0
# 3                     Lyn Cote  1998         1.0
# 4  National Geographic Society  2030         1.0
#
# Рекомендации для 'Nonexistent Book':
# Книга 'Nonexistent Book' не найдена.

# %%
import os
import numpy as np
import pandas as pd
import pickle
from cuml.feature_extraction.text import TfidfVectorizer
from cuml.metrics import pairwise_distances
from scipy.sparse import save_npz
import cupy as cp
import cudf

# Проверка доступности GPU
print("Доступно GPU:", cp.cuda.runtime.getDeviceCount())

books = pd.read_csv('clean_books.csv')
books_cudf = cudf.DataFrame.from_pandas(books)

books_pd = books_cudf.to_pandas()

# Инициализация TF-IDF на GPU
print("Инициализация TF-IDF...")
tfidf = TfidfVectorizer(
    stop_words='english',
    ngram_range=(1, 2),
    max_features=10000
)

# Создание TF-IDF матрицы на GPU
print("Создание TF-IDF матрицы...")
tfidf_matrix = tfidf.fit_transform(books_cudf['title'].fillna(''))

# Конвертация в разреженную матрицу CuPy для эффективных вычислений
tfidf_matrix_gpu = cp.sparse.csr_matrix(tfidf_matrix)

# Параметры рекомендаций
top_k = 5
n_books = len(books_cudf)
chunk_size = 2000  # Размер чанка для обработки

# Выделение памяти на GPU для результатов
top_indices = cp.zeros((n_books, top_k), dtype=cp.int32)
top_scores = cp.zeros((n_books, top_k), dtype=cp.float32)

# Функция для обработки чанка
def process_chunk(start_idx, end_idx):
    chunk_sim = 1 - pairwise_distances(
        tfidf_matrix_gpu[start_idx:end_idx],
        tfidf_matrix_gpu,
        metric='cosine'
    )

    for k in range(chunk_sim.shape[0]):
        book_idx = start_idx + k
        sim_scores = chunk_sim[k]
        sim_scores[book_idx] = -1  # Исключаем текущую книгу

        # Находим топ-5 на GPU
        top_5_indices = cp.argpartition(sim_scores, -top_k)[-top_k:]
        top_5_scores = sim_scores[top_5_indices]

        # Сортируем
        sorted_indices = cp.argsort(-top_5_scores)
        top_indices[book_idx] = top_5_indices[sorted_indices]
        top_scores[book_idx] = top_5_scores[sorted_indices]

# Вычисление рекомендаций по чанкам
print("Вычисление рекомендаций...")
for i in range(0, n_books, chunk_size):
    end_idx = min(i + chunk_size, n_books)
    print(f"Обработка книг {i}-{end_idx}...")
    process_chunk(i, end_idx)

# Перенос результатов на CPU
print("Перенос результатов на CPU...")
top_indices_cpu = cp.asnumpy(top_indices)
top_scores_cpu = cp.asnumpy(top_scores)

# Сохранение результатов
print("Сохранение результатов...")
np.save('top_5_indices.npy', top_indices_cpu)
np.save('top_5_scores.npy', top_scores_cpu)

# Сохранение модели TF-IDF
with open('tfidf_vectorizer.pkl', 'wb') as f:
    pickle.dump(tfidf, f)

# Сохранение TF-IDF матрицы
save_npz('tfidf_matrix.npz', tfidf_matrix)

# Сохранение метаданных
book_indices = pd.Series(books_pd.index, index=books_pd['title'].str.lower()).to_dict()
with open('book_indices.pkl', 'wb') as f:
    pickle.dump(book_indices, f)

print("Готово! Все файлы сохранены.")

# Опционально: скачивание файлов (для Google Colab)
# files.download('top_5_indices.npy')
# files.download('top_5_scores.npy')
# files.download('tfidf_vectorizer.pkl')
# files.download('tfidf_matrix.npz')
# files.download('book_indices.pkl')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-6-1432672081.py in <cell line: 0>()
#       3 import pandas as pd
#       4 import pickle
# ----> 5 from cuml.feature_extraction.text import TfidfVectorizer
#       6 from cuml.metrics import pairwise_distances
#       7 from scipy.sparse import save_npz
#
# ModuleNotFoundError: No module named 'cuml'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install --pre scikit-surprise -f https://surpriselib.com/wheels/
# Out:
# Looking in links: https://surpriselib.com/wheels/
# Requirement already satisfied: scikit-surprise in /usr/local/lib/python3.11/dist-packages (1.1.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-surprise) (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-surprise) (1.23.5)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-surprise) (1.15.3)

# %%
pip install scikit-surprise
# Out:
# Collecting scikit-surprise
#   Downloading scikit_surprise-1.1.4.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 5.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-surprise) (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-surprise) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-surprise) (1.15.3)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (pyproject.toml) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.4-cp311-cp311-linux_x86_64.whl size=2469552 sha256=336a0a0bcbc17be42d53f8685440a3ff3111a5c424448d7f1bb3bfd8b2f4f74b
#   Stored in directory: /root/.cache/pip/wheels/2a/8f/6e/7e2899163e2d85d8266daab4aa1cdabec7a6c56f83c015b5af
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.4

# %%
# recommenderSVD.py

import pandas as pd
from surprise import SVD, Dataset, Reader
from surprise.model_selection import train_test_split
from surprise import accuracy
import pickle

class SVDRecommender:
    def __init__(self, ratings_path='clean_ratings.csv', books_path='clean_books.csv'):
        self.ratings_df = pd.read_csv(ratings_path)
        self.books_df = pd.read_csv(books_path)
        self.model = None
        self.trainset = None
        self.reader = Reader(rating_scale=(1, 10))

    def train(self):
        data = Dataset.load_from_df(self.ratings_df[['user_id', 'isbn', 'rating']], self.reader)
        trainset, testset = train_test_split(data, test_size=0.2, random_state=42)
        self.model = SVD(n_factors=100, random_state=42)
        self.model.fit(trainset)
        predictions = self.model.test(testset)
        rmse = accuracy.rmse(predictions)
        print(f'✅ Model trained. RMSE: {rmse:.4f}')
        self.trainset = trainset

        # Сохраняем модель
        with open('svd_model.pkl', 'wb') as f:
            pickle.dump(self.model, f)

    def load_model(self):
        with open('svd_model.pkl', 'rb') as f:
            self.model = pickle.load(f)

    def recommend_books(self, user_id, top_n=10):
        if self.model is None or self.trainset is None:
            raise Exception("Сначала обучите или загрузите модель.")

        all_books = self.books_df['isbn'].unique()
        rated_books = self.ratings_df[self.ratings_df['user_id'] == user_id]['isbn'].tolist()
        books_to_predict = [isbn for isbn in all_books if isbn not in rated_books]

        predictions = [
            (isbn, self.model.predict(user_id, isbn).est)
            for isbn in books_to_predict
        ]
        predictions.sort(key=lambda x: x[1], reverse=True)
        top_books = predictions[:top_n]

        result_df = self.books_df[self.books_df['isbn'].isin([isbn for isbn, _ in top_books])]
        result_df = result_df[['title', 'author', 'year']]
        return result_df.reset_index(drop=True)


# Пример запуска
if __name__ == '__main__':
    recommender = SVDRecommender()
    recommender.train()
    recommendations = recommender.recommend_books(user_id=276729, top_n=5)
    print("Рекомендации:")
    print(recommendations)
# Out:
# RMSE: 1.6399
# ✅ Model trained. RMSE: 1.6399
# Рекомендации:
#                                              title            author  year
# 0                      Dune (Remembering Tomorrow)     Frank Herbert  1996
# 1   The Two Towers (The Lord of the Rings, Part 2)  J. R. R. Tolkien  1999
# 2                     Weirdos From Another Planet!    Bill Watterson  1990
# 3  52 Deck Series: 52 Ways to Celebrate Friendship       Lynn Gordon  2000
# 4     My Sister's Keeper : A Novel (Picoult, Jodi)      Jodi Picoult  2004

# %%
import pandas as pd
import numpy as np
import pickle
from scipy.sparse import load_npz, hstack
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from tqdm import tqdm
tqdm.pandas()
def load_models():
    """Загрузка предобученных моделей"""
    models = {}

    # Загрузка TF-IDF модели
    with open('tfidf_vectorizer.pkl', 'rb') as f:
        models['tfidf'] = pickle.load(f)
    models['tfidf_matrix'] = load_npz('tfidf_matrix.npz')

    # Загрузка SVD модели
    with open('svd_model.pkl', 'rb') as f:
        models['svd'] = pickle.load(f)

    # Загрузка дополнительных данных
    models['top_indices'] = np.load('top_5_indices.npy')
    models['top_scores'] = np.load('top_5_scores.npy')
    with open('book_indices.pkl', 'rb') as f:
        models['book_indices'] = pickle.load(f)

    return models

def generate_hybrid_features(books_path='clean_books.csv'):
    """Генерация гибридных признаков"""
    # Загрузка данных
    books = pd.read_csv(books_path)

    # Заполнение пропущенных значений
    books['title'] = books['title'].fillna('')
    books['publisher'] = books['publisher'].fillna('Unknown')
    books['author'] = books['author'].fillna('Unknown')
    books['year'] = books['year'].fillna(0).astype(int)

    # Загрузка предобученных моделей
    models = load_models()

    # 1. Используем готовую TF-IDF матрицу
    tfidf_features = models['tfidf_matrix']

    # 2. One-hot кодирование для авторов и издателей
    books['author_simplified'] = books['author'].apply(
        lambda x: x if books['author'].value_counts()[x] > 10 else 'Other')
    books['publisher_simplified'] = books['publisher'].apply(
        lambda x: x if books['publisher'].value_counts()[x] > 10 else 'Other')

    ohe = OneHotEncoder(handle_unknown='ignore', sparse=True)
    categorical_features = ohe.fit_transform(books[['author_simplified', 'publisher_simplified']])

    # 3. Масштабирование года издания
    scaler = MinMaxScaler()
    year_scaled = scaler.fit_transform(books[['year']])

    # 4. Добавляем SVD факторы (если нужно)
    # Для примера - используем первые 50 скрытых факторов
    svd_features = models['svd'].qi[:, :50]  # Факторы для книг

    # Объединение всех признаков
    X_hybrid = hstack([
        tfidf_features,
        categorical_features,
        year_scaled,
        svd_features
    ])

    # Сохранение результатов
    with open('X_hybrid_enhanced.pkl', 'wb') as f:
        pickle.dump({
            'X_hybrid': X_hybrid,
            'isbn_list': books['isbn'].tolist(),
            'title_list': books['title'].tolist(),
            'books_df': books,
            'onehot_encoder': ohe,
            'scaler': scaler,
            'feature_types': ['tfidf', 'categorical', 'year', 'svd_factors']
        }, f)

    print("✅ Гибридные признаки сохранены в X_hybrid_enhanced.pkl")
    print(f"Общая размерность признаков: {X_hybrid.shape[1]}")
    return X_hybrid

if __name__ == '__main__':
    generate_hybrid_features()

# %%
import pandas as pd
import numpy as np
import pickle
from scipy.sparse import load_npz, hstack
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from tqdm import tqdm
tqdm.pandas()
def load_models():
    """Загрузка предобученных моделей"""
    models = {}

    # Загрузка TF-IDF модели
    with open('tfidf_vectorizer.pkl', 'rb') as f:
        models['tfidf'] = pickle.load(f)
    models['tfidf_matrix'] = load_npz('tfidf_matrix.npz')

    # Загрузка SVD модели
    with open('svd_model.pkl', 'rb') as f:
        models['svd'] = pickle.load(f)

    # Загрузка дополнительных данных
    models['top_indices'] = np.load('top_5_indices.npy')
    models['top_scores'] = np.load('top_5_scores.npy')
    with open('book_indices.pkl', 'rb') as f:
        models['book_indices'] = pickle.load(f)

    return models

def generate_hybrid_features(books_path='clean_books.csv'):
    """Генерация гибридных признаков"""
    # Загрузка данных
    books = pd.read_csv(books_path)

    # Заполнение пропущенных значений
    books['title'] = books['title'].fillna('')
    books['publisher'] = books['publisher'].fillna('Unknown')
    books['author'] = books['author'].fillna('Unknown')
    books['year'] = books['year'].fillna(0).astype(int)

    # Загрузка предобученных моделей
    models = load_models()

    # 1. Используем готовую TF-IDF матрицу
    tfidf_features = models['tfidf_matrix']

    # 2. One-hot кодирование для авторов и издателей
    author_counts = books['author'].value_counts()
    publisher_counts = books['publisher'].value_counts()

    # Векторизованная обработка (в 100+ раз быстрее)
    books['author_simplified'] = np.where(
        books['author'].map(author_counts) > 10,
        books['author'],
        'Other'
    )

    books['publisher_simplified'] = np.where(
        books['publisher'].map(publisher_counts) > 10,
        books['publisher'],
        'Other'
    )

    ohe = OneHotEncoder(handle_unknown='ignore', sparse_output=True)
    categorical_features = ohe.fit_transform(books[['author_simplified', 'publisher_simplified']])

    # 3. Масштабирование года издания
    scaler = MinMaxScaler()
    year_scaled = scaler.fit_transform(books[['year']])

    # 4. Добавляем SVD факторы (если нужно)
    # Для примера - используем первые 50 скрытых факторов
    n_books = tfidf_features.shape[0]  # Получаем общее количество книг из TF-IDF
    svd_n_books = models['svd'].qi.shape[0]  # Количество книг в SVD модели
    if svd_n_books < n_books:
        # Дополняем нулями недостающие строки
        padding = np.zeros((n_books - svd_n_books, 50))
        svd_features = np.vstack([models['svd'].qi[:, :50], padding])
    else:
        svd_features = models['svd'].qi[:n_books, :50]

    # Объединение всех признаков
    X_hybrid = hstack([
        tfidf_features,
        categorical_features,
        year_scaled,
        svd_features
    ])

    # Сохранение результатов
    with open('X_hybrid_enhanced.pkl', 'wb') as f:
        pickle.dump({
            'X_hybrid': X_hybrid,
            'isbn_list': books['isbn'].tolist(),
            'title_list': books['title'].tolist(),
            'books_df': books,
            'onehot_encoder': ohe,
            'scaler': scaler,
            'feature_types': ['tfidf', 'categorical', 'year', 'svd_factors']
        }, f)

    print("✅ Гибридные признаки сохранены в X_hybrid_enhanced.pkl")
    print(f"Общая размерность признаков: {X_hybrid.shape[1]}")
    return X_hybrid

if __name__ == '__main__':
    generate_hybrid_features()
# Out:
# ✅ Гибридные признаки сохранены в X_hybrid_enhanced.pkl
# Общая размерность признаков: 10938

# %%
# Переобучите SVD модель на том же наборе книг, что и TF-IDF

print(f"Предупреждение: SVD обучена на {svd_n_books} книгах, а TF-IDF на {n_books}")
print("Рекомендуется переобучить SVD на полном наборе данных")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-5-538775870.py in <cell line: 0>()
#       1 # Переобучите SVD модель на том же наборе книг, что и TF-IDF
# ----> 2 print(f"Предупреждение: SVD обучена на {svd_n_books} книгах, а TF-IDF на {n_books}")
#       3 print("Рекомендуется переобучить SVD на полном наборе данных")
#
# NameError: name 'svd_n_books' is not defined

# %%
import pickle
with open('X_hybrid_enhanced.pkl', 'rb') as f:
    data = pickle.load(f)
    print(data.keys())
# Out:
# dict_keys(['X_hybrid', 'isbn_list', 'title_list', 'books_df', 'onehot_encoder', 'scaler', 'feature_types'])

# %%
import pickle
from surprise import SVD

# Загружаем модель как обычно
with open('svd_model.pkl', 'rb') as f:
    model = pickle.load(f)

# Пересохраняем веса модели в универсальном формате
model_weights = {
    'pu': model.pu,  # user factors
    'qi': model.qi,  # item factors
    'bu': model.bu,  # user biases
    'bi': model.bi,  # item biases
}

# Сохраняем веса в JSON или numpy-формате
import numpy as np
np.savez('svd_weights.npz', **model_weights)
